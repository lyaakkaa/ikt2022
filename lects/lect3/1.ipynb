# %%
import csv
import pandas as pd
df = pd.DataFrame({"Brand" : ["Cola", "Pepsi", "Sprite", "water"], "Taste" : [5, 6, 9, 8], "Content" : ["High", "High", "Low", "Low"]} )
print(df)
# Out:
#     Brand  Taste Content
# 0    Cola      5    High
# 1   Pepsi      6    High
# 2  Sprite      9     Low
# 3   water      8     Low

# %%
import csv
import pandas as pd
brand = ["Cola", "Pepsi", "Sprite", "water"]
taste = [5, 6, 9, 8]
sugar = ["High", "High", "Low", "Low"]
list1 = [0, 1, 2]
df = pd.DataFrame(zip([brand], brand) )
print(df)
# Out:
#                               0     1
# 0  [Cola, Pepsi, Sprite, water]  Cola

# %%
import csv
import pandas as pd

df = pd.read_csv( r"C:\Users\leila\OneDrive\Рабочий стол\IKT\practice2\CL.csv",
                parse_dates = ["Date"]
                )
df = df.sort_values("Open")
df = df.reset_index(drop = True)
print(df)
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     1973-05-02   0.000000   2.000000   1.966146   2.000000   0.470298
# 1     1975-10-01   0.000000   1.703125   1.656250   1.679688   0.415538
# 2     1975-10-02   0.000000   1.726563   1.679688   1.718750   0.425201
# 3     1975-10-03   0.000000   1.804688   1.734375   1.804688   0.446462
# 4     1975-10-06   0.000000   1.820313   1.773438   1.789063   0.442596
# ...          ...        ...        ...        ...        ...        ...
# 12443 2020-11-18  85.639999  85.940002  84.599998  84.610001  81.297668
# 12444 2020-12-18  85.660004  86.199997  84.959999  85.930000  82.565987
# 12445 2020-12-01  85.760002  86.339996  85.379997  86.260002  82.883080
# 12446 2020-12-29  85.830002  86.209999  84.919998  85.029999  81.701218
# 12447 2020-12-02  86.070000  86.379997  85.250000  85.739998  82.383430
#
#         Volume
# 0       672000
# 1       377600
# 2       329600
# 3       350400
# 4       376000
# ...

# %%
import csv
import pandas as pd

df = pd.read_csv( r"C:\Users\leila\OneDrive\Рабочий стол\IKT\practice2\CL.csv",
                parse_dates = ["Date"]
                )
# df = df.sort_values("Open")
# df = df.reset_index(drop = True)
# print(df)
df.plot(x = "Date", y = "High")
# Out:
# <AxesSubplot: xlabel='Date'>
