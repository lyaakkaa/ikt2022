# %% [markdown]
# # LECTURE 6

# %% [markdown]
# # Correction of the practice

# %%
import requests

# %%
headers = {'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:105.0) Gecko/20100101 Firefox/105.0'}
resp = requests.get('https://query1.finance.yahoo.com/v7/finance/download/MSFT?period1=1633828168&period2=1665364168&interval=1d&events=history&includeAdjustedClose=true', 
                    headers = headers)

print(resp.content)

# %%
import pandas as pd
import io
df = pd.read_csv(io.StringIO(resp.content.decode('utf-8')))
print(df)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2021-10-11  292.920013  297.970001  292.750000  294.230011  291.786316
# 1    2021-10-12  295.339996  295.440002  292.350006  292.880005  290.447479
# 2    2021-10-13  294.910004  297.279999  293.489990  296.309998  293.848969
# 3    2021-10-14  299.209991  303.269989  297.829987  302.750000  300.235504
# 4    2021-10-15  302.339996  304.450012  300.519989  304.209991  301.683411
# ..          ...         ...         ...         ...         ...         ...
# 246  2022-10-03  235.410004  241.610001  234.660004  240.740005  240.740005
# 247  2022-10-04  245.089996  250.360001  244.979996  248.880005  248.880005
# 248  2022-10-05  245.990005  250.580002  244.100006  249.199997  249.199997
# 249  2022-10-06  247.929993  250.339996  246.080002  246.789993  246.789993
# 250  2022-10-07  240.899994  241.320007  233.169998  234.240005  234.240005
#
#        Volume
# 0    19298600
# 1    17974100
# 2    23416300
# 3    27262900
# 4    25384800
# ..        ...
# 246  28880400
# 247  34888400
# 248  20347100
# 249  20239900
# 250  37732400
#
# [251 rows x 7 columns]

# %%
df = pd.read_csv('https://query1.finance.yahoo.com/v7/finance/download/MSFT?period1=1633828168&period2=1665364168&interval=1d&events=history&includeAdjustedClose=true')
print(df)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2021-10-11  292.920013  297.970001  292.750000  294.230011  291.786316
# 1    2021-10-12  295.339996  295.440002  292.350006  292.880005  290.447510
# 2    2021-10-13  294.910004  297.279999  293.489990  296.309998  293.848999
# 3    2021-10-14  299.209991  303.269989  297.829987  302.750000  300.235504
# 4    2021-10-15  302.339996  304.450012  300.519989  304.209991  301.683380
# ..          ...         ...         ...         ...         ...         ...
# 246  2022-10-03  235.410004  241.610001  234.660004  240.740005  240.740005
# 247  2022-10-04  245.089996  250.360001  244.979996  248.880005  248.880005
# 248  2022-10-05  245.990005  250.580002  244.100006  249.199997  249.199997
# 249  2022-10-06  247.929993  250.339996  246.080002  246.789993  246.789993
# 250  2022-10-07  240.899994  241.320007  233.169998  234.240005  234.240005
#
#        Volume
# 0    19298600
# 1    17974100
# 2    23416300
# 3    27262900
# 4    25384800
# ..        ...
# 246  28880400
# 247  34888400
# 248  20347100
# 249  20239900
# 250  37732400
#
# [251 rows x 7 columns]

# %%
l = ['TSLA', 'MSFT', 'AAPL']
for i in l:
    headers = {'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:105.0) Gecko/20100101 Firefox/105.0'}
    resp = requests.get('https://query1.finance.yahoo.com/v7/finance/download/'+i+'?period1=1633828168&period2=1665364168&interval=1d&events=history&includeAdjustedClose=true', 
                        headers = headers)

    import pandas as pd
    import io
    df = pd.read_csv(io.StringIO(resp.content.decode('utf-8')))
    print(df)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2021-10-11  262.549988  267.079987  261.833344  263.980011  263.980011
# 1    2021-10-12  266.976654  270.773346  265.523346  268.573334  268.573334
# 2    2021-10-13  270.156677  271.803345  268.593323  270.359985  270.359985
# 3    2021-10-14  271.829987  273.416656  271.116669  272.773346  272.773346
# 4    2021-10-15  274.579987  281.070007  274.116669  281.010010  281.010010
# ..          ...         ...         ...         ...         ...         ...
# 246  2022-10-03  254.500000  255.160004  241.009995  242.399994  242.399994
# 247  2022-10-04  250.520004  257.500000  242.009995  249.440002  249.440002
# 248  2022-10-05  245.009995  246.669998  233.270004  240.809998  240.809998
# 249  2022-10-06  239.440002  244.580002  235.350006  238.130005  238.130005
# 250  2022-10-07  233.940002  234.570007  222.020004  223.070007  223.070007
#
#         Volume
# 0     42600900
# 1     66060000
# 2     42360300
# 3     36741600
# 4     56773800
# ..         ...
# 246   98363500
# 247  109578500
# 248   86982700
# 249   69298400
# 250   83592300
#
# [251 rows x 7 columns]
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2021-10-11  292.920013  297.970001  292.750000  294.230011  291.786316
# 1    2021-10-12  295.339996  295.440002  292.350006  292.880005  290.447479
# 2    2021-10-13  294.910004  297.279999  293.489990  296.309998  293.848969
# 3    2021-10-14  299.209991  303.269989  297.829987  302.750000  300.235504
# 4    2021-10-15  302.339996  304.450012  300.519989  304.209991  301.683411
# ..          ...         ...         ...         ...         ...         ...
# 246  2022-10-03  235.410004  241.610001  234.660004  240.740005  240.740005
# 247  2022-10-04  245.089996  250.360001  244.979996  248.880005  248.880005
# 248  2022-10-05  245.990005  250.580002  244.100006  249.199997  249.199997
# 249  2022-10-06  247.929993  250.339996  246.080002  246.789993  246.789993
# 250  2022-10-07  240.899994  241.320007  233.169998  234.240005  234.240005
#
#        Volume
# 0    19298600
# 1    17974100
# 2    23416300
# 3    27262900
# 4    25384800
# ..        ...
# 246  28880400
# 247  34888400
# 248  20347100
# 249  20239900
# 250  37732400
#
# [251 rows x 7 columns]
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2021-10-11  142.270004  144.809998  141.809998  142.809998  142.014206
# 1    2021-10-12  143.229996  143.250000  141.039993  141.509995  140.721451
# 2    2021-10-13  141.240005  141.399994  139.199997  140.910004  140.124802
# 3    2021-10-14  142.110001  143.880005  141.509995  143.759995  142.958908
# 4    2021-10-15  143.770004  144.899994  143.509995  144.839996  144.032898
# ..          ...         ...         ...         ...         ...         ...
# 246  2022-10-03  138.210007  143.070007  137.690002  142.449997  142.449997
# 247  2022-10-04  145.029999  146.220001  144.259995  146.100006  146.100006
# 248  2022-10-05  144.070007  147.380005  143.009995  146.399994  146.399994
# 249  2022-10-06  145.809998  147.539993  145.220001  145.429993  145.429993
# 250  2022-10-07  142.539993  143.100006  139.449997  140.089996  140.089996
#
#         Volume
# 0     64452200
# 1     73035900
# 2     78762700
# 3     69907100
# 4     67940300
# ..         ...
# 246  114311700
# 247   87830100
# 248   79471000
# 249   68402200
# 250   85859100
#
# [251 rows x 7 columns]

# %% [markdown]
# # LECTURE

# %% [markdown]
# # Reminder => make a request

# %%
#YOUR TURN: Make a request to any website (except websites with login requiered) and print the html code
#10 minutes => just print the content of the response => 17:30

# %%
#install and import request library
import requests

# %%
#make a request
resp = requests.get('https://www.google.com')
print(resp.content)

# %%
#Use header with user-agent information for better result
headers = {'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:105.0) Gecko/20100101 Firefox/105.0'}
resp = requests.get('https://www.google.com', headers = headers)
print(resp.content)
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="kk"><head><meta charset="UTF-8"><meta content="origin" name="referrer"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><link href="/manifest?pwa=webhp" crossorigin="use-credentials" rel="manifest"><title>Google</title><script nonce="RqtVga-iBfx8sDzQBSSPRw">(function(){window.google={kEI:\'9DZVY-P7NqOOrwTNmZvIDQ\',kEXPI:\'31\',kBL:\'CvBf\'};google.sn=\'webhp\';google.kHL=\'kk\';})();(function(){\nvar f=this||self;var h,k=[];function l(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||h}function m(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b}\nfunction n(a,b,c,d,g){var e="";c||-1!==b.search("&ei=")||(e="&ei="+l(d),-1===b.search("&lei=")&&(d=m(d))&&(e+="&lei="+d));d="";!c&&f._cshid&&-1===b.search("&cshid=")&&"slh"!==a&&(d="&cshid="+f._cshid);c=c||"/"+(g||"gen_204")+"?atyp=i&ct="+a+"&cad="+b+e+"&zx="+Date.now()+d;/^http:/i.test(c)&&"https:"===window.location.protocol&&(google.ml&&google.ml(Error("a"),!1,{src:c,glmm:1}),c="");return c};h=google.kEI;google.getEI=l;google.getLEI=m;google.ml=function(){return null};google.log=function(a,b,c,d,g){if(c=n(a,b,c,d,g)){a=new Image;var e=k.length;k[e]=a;a.onerror=a.onload=a.onabort=function(){delete k[e]};a.src=c}};google.logUrl=n;}).call(this);(function(){\ngoogle.y={};google.sy=[];google.x=function(a,b){if(a)var c=a.id;else{do c=Math.random();while(google.y[c])}google.y[c]=[a,b];return!1};google.sx=function(a){google.sy.push(a)};google.lm=[];google.plm=function(a){google.lm.push.apply(google.lm,a)};google.lq=[];google.load=function(a,b,c){google.lq.push([[a],b,c])};google.loadAll=function(a,b){google.lq.push([a,b])};google.bx=!1;google.lx=function(){};}).call(this);google.f={};(function(){\ndocument.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c||"q"===c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if("A"===a.tagName){a="1"===a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){google.hs={h:true,nhs:false,sie:false};})();(function(){google.c={ataf:false,btfi:false,cap:2000,fil:false,frt:false,gecoh:true,gl:true,lhc:false,logo:false,raf:false,sxs:false,taf:false,timl:false};})();(function(){\nvar f=this||self;var g=window.performance;function h(a,b,d,c){a.addEventListener?a.addEventListener(b,d,c||!1):a.attachEvent&&a.attachEvent("on"+b,d)}function k(a,b,d,c){"addEventListener"in a?a.removeEventListener(b,d,c||!1):a.attachEvent&&a.detachEvent("on"+b,d)};google.c.iim=google.c.iim||{};function l(a){a&&f.google.aft(a.target)}var m;function n(){k(document.documentElement,"load",m,!0);k(document.documentElement,"error",m,!0)};google.timers={};google.startTick=function(a){google.timers[a]={t:{start:Date.now()},e:{},m:{}}};google.tick=function(a,b,d){google.timers[a]||google.startTick(a);d=void 0!==d?d:Date.now();b instanceof Array||(b=[b]);for(var c=0,e;e=b[c++];)google.timers[a].t[e]=d};google.c.e=function(a,b,d){google.timers[a].e[b]=d};google.c.b=function(a,b){b=google.timers[b||"load"].m;b[a]&&google.ml(Error("a"),!1,{m:a});b[a]=!0};google.c.u=function(a,b){var d=google.timers[b||"load"],c=d.m;if(c[a]){c[a]=!1;for(a in c)if(c[a])return;google.csiReport(d,"load2"===b?"all2":"all")}else{b="";for(var e in c)b+=e+":"+c[e]+";";google.ml(Error("b"),!1,{m:a,b:!1===c[a],s:b})}};google.rll=function(a,b,d){function c(e){d(e);k(a,"load",c);k(a,"error",c)}h(a,"load",c);b&&h(a,"error",c)};f.google.aft=function(a){a.setAttribute("data-iml",String(Date.now()))};google.startTick("load");var p=google.timers.load;a:{var q=p.t;if(g){var r=g.timing;if(r){var t=r.navigationStart,u=r.responseStart;if(u>t&&u<=q.st ...

# %% [markdown]
# # BeautifulSoup and Html

# %% [markdown]
# ## Reminder

# %%
#Get the html file of a website
with open(r"D:\KBTU\2022-2023\Python Course\Course\Lecture\Lecture_6\html_example.html", 'r') as file:
    content = file.read()
    
print(content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\leila\OneDrive\Рабочий стол\IKT\lects\lect6\Lecture_6_correction.ipynb Ячейка 16 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/leila/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/IKT/lects/lect6/Lecture_6_correction.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> #Get the html file of a website
# ----> <a href='vscode-notebook-cell:/c%3A/Users/leila/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/IKT/lects/lect6/Lecture_6_correction.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> with open(r"D:\KBTU\2022-2023\Python Course\Course\Lecture\Lecture_6\html_example.html", 'r') as file:
#       <a href='vscode-notebook-cell:/c%3A/Users/leila/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/IKT/lects/lect6/Lecture_6_correction.ipynb#X21sZmlsZQ%3D%3D?line=2'>3</a>     content = file.read()
#       <a href='vscode-notebook-cell:/c%3A/Users/leila/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/IKT/lects/lect6/Lecture_6_correction.ipynb#X21sZmlsZQ%3D%3D?line=4'>5</a> print(content)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\KBTU\\2022-2023\\Python Course\\Course\\Lecture\\Lecture_6\\html_example.html'

# %%
#Install an import beautiful soup
# for installation => pip install bs4
from bs4 import BeautifulSoup

# %%
#Make the soup !
# content is resp.content (where resp = requests.get(....))
soup = BeautifulSoup(content)
print(soup.prettify())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\leila\OneDrive\Рабочий стол\IKT\lects\lect6\Lecture_6_correction.ipynb Ячейка 18 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/leila/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/IKT/lects/lect6/Lecture_6_correction.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> #Make the soup !
#       <a href='vscode-notebook-cell:/c%3A/Users/leila/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/IKT/lects/lect6/Lecture_6_correction.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> # content is resp.content (where resp = requests.get(....))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/leila/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/IKT/lects/lect6/Lecture_6_correction.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a> soup = BeautifulSoup(content)
#       <a href='vscode-notebook-cell:/c%3A/Users/leila/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/IKT/lects/lect6/Lecture_6_correction.ipynb#X23sZmlsZQ%3D%3D?line=3'>4</a> print(soup.prettify())
#
# NameError: name 'content' is not defined

# %%
#YOUR TURN
#Make a soup of athe weather website (link on teams)
#10 minutes => 17:44
headers = {'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:105.0) Gecko/20100101 Firefox/105.0'}
resp = requests.get('https://www.accuweather.com/en/kz/almaty/222191/weather-forecast/222191', headers = headers)
soup = BeautifulSoup(resp.content)
print(soup.prettify())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\leila\OneDrive\Рабочий стол\IKT\lects\lect6\Lecture_6_correction.ipynb Ячейка 19 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/leila/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/IKT/lects/lect6/Lecture_6_correction.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> #YOUR TURN
#       <a href='vscode-notebook-cell:/c%3A/Users/leila/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/IKT/lects/lect6/Lecture_6_correction.ipynb#X24sZmlsZQ%3D%3D?line=1'>2</a> #Make a soup of athe weather website (link on teams)
#       <a href='vscode-notebook-cell:/c%3A/Users/leila/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/IKT/lects/lect6/Lecture_6_correction.ipynb#X24sZmlsZQ%3D%3D?line=2'>3</a> #10 minutes => 17:44
#       <a href='vscode-notebook-cell:/c%3A/Users/leila/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/IKT/lects/lect6/Lecture_6_correction.ipynb#X24sZmlsZQ%3D%3D?line=3'>4</a> headers = {'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:105.0) Gecko/20100101 Firefox/105.0'}
# ----> <a href='vscode-notebook-cell:/c%3A/Users/leila/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/IKT/lects/lect6/Lecture_6_correction.ipynb#X24sZmlsZQ%3D%3D?line=4'>5</a> resp = requests.get('https://www.accuweather.com/en/kz/almaty/222191/weather-forecast/222191', headers = headers)
#       <a href='vscode-notebook-cell:/c%3A/Users/leila/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/IKT/lects/lect6/Lecture_6_correction.ipynb#X24sZmlsZQ%3D%3D?line=5'>6</a> soup = BeautifulSoup(resp.content)
#       <a href='vscode-notebook-cell:/c%3A/Users/leila/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/IKT/lects/lect6/Lecture_6_correction.ipynb#X24sZmlsZQ%3D%3D?line=6'>7</a> print(soup.prettify())
#
# NameError: name 'requests' is not defined

# %% [markdown]
# # Using the soup

# %% [markdown]
# ## Some useful functions

# %%
#Getting a html file in my files
with open(r"D:\KBTU\2022-2023\Python Course\Course\Lecture\Lecture_6\html_example.html", 'r') as file:
    content = file.read()
    
# print(content)
soup = BeautifulSoup(content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\leila\OneDrive\Рабочий стол\IKT\lects\lect6\Lecture_6_correction.ipynb Ячейка 22 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/leila/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/IKT/lects/lect6/Lecture_6_correction.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> #Getting a html file in my files
# ----> <a href='vscode-notebook-cell:/c%3A/Users/leila/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/IKT/lects/lect6/Lecture_6_correction.ipynb#X30sZmlsZQ%3D%3D?line=1'>2</a> with open(r"D:\KBTU\2022-2023\Python Course\Course\Lecture\Lecture_6\html_example.html", 'r') as file:
#       <a href='vscode-notebook-cell:/c%3A/Users/leila/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/IKT/lects/lect6/Lecture_6_correction.ipynb#X30sZmlsZQ%3D%3D?line=2'>3</a>     content = file.read()
#       <a href='vscode-notebook-cell:/c%3A/Users/leila/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/IKT/lects/lect6/Lecture_6_correction.ipynb#X30sZmlsZQ%3D%3D?line=4'>5</a> # print(content)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\KBTU\\2022-2023\\Python Course\\Course\\Lecture\\Lecture_6\\html_example.html'

# %%
# prettify
print(soup.prettify())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\leila\OneDrive\Рабочий стол\IKT\lects\lect6\Lecture_6_correction.ipynb Ячейка 23 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/leila/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/IKT/lects/lect6/Lecture_6_correction.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> # prettify
# ----> <a href='vscode-notebook-cell:/c%3A/Users/leila/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/IKT/lects/lect6/Lecture_6_correction.ipynb#X31sZmlsZQ%3D%3D?line=1'>2</a> print(soup.prettify())
#
# NameError: name 'soup' is not defined

# %%
# Going trough tags
print(soup.div.div)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\leila\OneDrive\Рабочий стол\IKT\lects\lect6\Lecture_6_correction.ipynb Ячейка 24 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/leila/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/IKT/lects/lect6/Lecture_6_correction.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> # Going trough tags
# ----> <a href='vscode-notebook-cell:/c%3A/Users/leila/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/IKT/lects/lect6/Lecture_6_correction.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a> print(soup.div.div)
#
# NameError: name 'soup' is not defined

# %%
#YOUR TURN print the following tag ...
headers = {'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:105.0) Gecko/20100101 Firefox/105.0'}
resp = requests.get('https://www.accuweather.com/en/kz/almaty/222191/weather-forecast/222191', headers = headers)
soup = BeautifulSoup(resp.content, 'html.parser')
print(type(soup.body.div.div.div.div.div))
# Out:
# <class 'bs4.element.Tag'>

# %%
# iteration on children of a tag:
with open(r"D:\KBTU\2022-2023\Python Course\Course\Lecture\Lecture_6\html_example.html", 'r') as file:
    content = file.read()
    
# print(content)
soup = BeautifulSoup(content)

# for child in soup.aside.ul.children:
#     print(child)

# %%
#On all descendant

for child in soup.header.descendants:
    print(child)

# %%
#YOUR TURN : print all descendats  of a tag: div class = "template-root"
#5 minutes
headers = {'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:105.0) Gecko/20100101 Firefox/105.0'}
resp = requests.get('https://www.accuweather.com/en/kz/almaty/222191/weather-forecast/222191', headers = headers)
soup = BeautifulSoup(resp.content, 'html.parser')
for desc in soup.body.div.descendants:
    print(desc)
# Out:
# <div class="nfl-header">
# <div class="header-outer">
# <div class="header-inner">
# <a class="header-logo" href="/">
# <svg data-eager="" height="24" viewbox="0 0 189 27" width="168" xmlns="http://www.w3.org/2000/svg"><g fill="none"><path d="M183.058 22.739v-6.864c0-1.4.293-2.342.879-2.83.585-.488 1.561-.716 2.863-.716h1.269v-3.09h-1.074c-.976 0-1.822.13-2.505.422a4.054 4.054 0 0 0-1.66 1.237l-.65-1.66h-2.44v13.5h3.318zM171.28 11.743c.944 0 1.66.26 2.148.814.488.553.748 1.268.813 2.147h-6.117c.065-.911.326-1.627.814-2.147.488-.553 1.204-.814 2.147-.814h.195zm2.766 6.93c-.228.487-.553.878-.976 1.138-.423.293-.944.423-1.627.423h-.228c-1.008 0-1.757-.293-2.277-.846-.52-.553-.814-1.301-.879-2.18h9.469v-1.366c0-2.114-.553-3.806-1.66-5.042-1.106-1.269-2.635-1.887-4.555-1.887h-.228c-1.92 0-3.449.618-4.588 1.887-1.138 1.236-1.692 2.863-1.692 4.847v.878c0 .976.163 1.855.456 2.668a5.877 5.877 0 0 0 1.269 2.082 5.83 5.83 0 0 0 2.017 1.366c.814.325 1.692.488 2.7.488h.229c1.269 0 2.342-.26 3.253-.748s1.66-1.236 2.213-2.245l-2.896-1.464zm-20.271 4.066v-7.873c.033-.91.26-1.659.716-2.244.455-.586 1.139-.879 1.985-.879h.325c.748 0 1.334.228 1.757.716.456.455.65 1.236.65 2.31v8.002h3.32v-8.588c0-1.594-.423-2.863-1.302-3.838-.878-.976-2.017-1.464-3.481-1.464h-.39c-.717 0-1.4.13-2.018.423a5.332 5.332 0 0 0-1.627 1.17V3.84h-3.319v18.9h3.384zm-8.688-2.96c-.227-.196-.325-.554-.325-1.074v-6.799h3.254V9.239h-3.254v-2.96h-2.83l-.359 2.96h-2.212v2.667h2.115v6.831c0 1.236.293 2.212.878 2.928.586.716 1.595 1.074 2.994 1.074h2.635V20.07h-1.92c-.455 0-.78-.098-.976-.293zm-13.828.52c-.683 0-1.204-.13-1.562-.39-.358-.26-.553-.651-.553-1.14v-.097c0-.488.195-.91.618-1.236.39-.325 1.106-.488 2.148-.488h2.472v.488c0 .976-.26 1.692-.78 2.147-.521.456-1.237.716-2.083.716h-.26zm-.65 2.797c.878 0 1.626-.162 2.31-.488.683-.325 1.236-.813 1.691-1.496l.553 1.66h2.506v-8.85c0-1.658-.488-2.927-1.464-3.773-.977-.845-2.343-1.268-4.068-1.268h-.325c-1.562 0-2.798.325-3.71.943-.91.65-1.496 1.431-1.756 2.342l2.928 1.204c.163-.456.456-.813.846-1.139.39-.292.944-.455 1.627-.455h.325c.781 0 1.367.195 1.725.553.39.39.553.91.553 1.594v.683h-2.408c-1.985 0-3.481.39-4.523 1.171-1.04.78-1.561 1.822-1.561 3.09v.196c0 1.268.39 2.244 1.17 2.992.782.716 1.888 1.106 3.32 1.106h.26v-.065zm-12.495-11.353c.943 0 1.659.26 2.147.814.488.553.748 1.268.813 2.147h-6.117c.065-.911.326-1.627.814-2.147.488-.553 1.204-.814 2.147-.814h.196zm2.765 6.93c-.228.487-.553.878-.976 1.138-.423.293-.943.423-1.627.423h-.228c-1.008 0-1.757-.293-2.277-.846-.52-.553-.814-1.301-.879-2.18h9.469v-1.366c0-2.114-.553-3.806-1.66-5.042-1.106-1.269-2.635-1.887-4.555-1.887h-.26c-1.92 0-3.45.618-4.588 1.887-1.139 1.236-1.692 2.863-1.692 4.847v.878c0 .976.163 1.855.455 2.668a5.877 5.877 0 0 0 1.27 2.082 5.83 5.83 0 0 0 2.017 1.366c.813.325 1.692.488 2.7.488h.228c1.27 0 2.343-.26 3.254-.748s1.66-1.236 2.213-2.245l-2.864-1.464zM95.76 22.738l3.97-13.76 3.774 13.76h3.026l5.434-18.673V3.84h-3.254l-3.58 13.37-3.513-13.37h-3.58L94.36 17.436 90.878 3.84h-3.416v.227l5.206 18.673h3.091zm-21.312-13.5v8.555c0 1.594.423 2.863 1.301 3.839.879.975 2.018 1.463 3.482 1.463h.358c.813 0 1.561-.162 2.212-.488.684-.325 1.237-.813 1.692-1.43l.553 1.56h2.473v-13.5h-3.286v7.873c-.033.91-.26 1.659-.748 2.244-.489.586-1.14.879-2.018.879h-.325c-.716 0-1.302-.228-1.757-.716-.456-.455-.684-1.236-.684-2.31V9.206h-3.253v.033zm-3.645.553c-.91-.586-2.082-.879-3.546-.879h-.228c-1.92 0-3.449.553-4.588 1.692-1.139 1.138-1.692 2.635-1.692 4.522v1.724c0 1.886.553 3.415 1.692 4.521 1.139 1.139 2.636 1.692 4.588 1.692h.228c1.334 0 2.44-.26 3.319-.78.878-.521 1.561-1.27 2.082-2.31l-2.733-1.53a3.17 3.17 0 0 1-.976 1.27c-.423.325-.976.487-1.692.487h-.228c-1.041 0-1.79-.325-2.278-.943-.488-.618-.715-1.431-.715-2.44V15.16c0-1.008.227-1.822.715-2.44.488-.618 1.237-.943 2.278-.943h.228c.716 0 1.301.163 1.724.488.423.325.749.78.976 1.334l2.864-1.367c-.423-1.008-1.107-1.854-2.018-2.44zm-13.308 0c-.91-.586-2.082-.879-3.546-.879h-.228c-1.92 0-3.449.553-4.588 1.692-1.139 1.138-1.692 2.635-1.692 4.522v1.724c0 1.886.553 3.415 1.692 4.521 1.139 1.139 2.636 1.692 4.588 1.692h.228c1.334 0 2.44-.26 3 ...
# </a>
# <a class="header-city-link" href="/en/kz/almaty/222191/weather-forecast/222191">
# <h1 class="header-loc">Almaty, Almaty</h1>
# <span class="header-temp">
# 						7°
# 						<span class="unit">C</span>
# </span>
# <svg class="header-weather-icon" data-src="/images/weathericons/18.svg" height="27" viewbox="0 0 288 288" width="27"><g fill="none" fill-rule="evenodd" stroke-width="9.796"><path d="M204.873 168.698c31.109 0 56.327-25.218 56.327-56.327 0-31.108-25.218-56.326-56.327-56.326h-9.649c-17.997-21.189-47.006-29.414-73.446-20.826-26.44 8.588-45.079 32.29-47.19 60.01H62.784c-20.288 0-36.735 16.446-36.735 36.734s16.447 36.735 36.735 36.735h142.09Z" stroke="#BABABA"></path><path d="m50.44 234.429 26.842-45.992M121.657 234.429l26.841-45.992M72.53 257.645l40.36-69.208M194.294 234.429l26.84-45.992M145.118 257.645l40.409-69.208" stroke="#288ADB"></path></g></svg>
# </a>
# <div class="pull-right">
# <div class="header-search-bar search-bar">
# <div class="searchbar-inner">
# <svg class="icon-search" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M7.186 13.554c-3.462 0-6.303-2.869-6.303-6.359C.883 3.681 3.724.837 7.186.837c3.437 0 6.278 2.844 6.278 6.358 0 3.49-2.865 6.359-6.278 6.359zm5.323-1.602a7.176 7.176 0 0 0 1.815-4.757c0-3.968-3.2-7.195-7.138-7.195C3.223 0 0 3.227 0 7.195c0 3.944 3.223 7.171 7.186 7.171a7.058 7.058 0 0 0 4.75-1.84L17.427 18l.573-.55-5.49-5.498z" transform="translate(3 3)"></path></svg>
# <form action="/en/search-locations" class="search-form" method="GET">
# <input autocomplete="off" class="search-input" name="query" placeholder="Search" type="text"/>
# </form>
# <svg class="clear-icon close-icon" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><g fill-rule="evenodd" transform="translate(-1 -1)"><rect height="24" rx="1" transform="rotate(45 10 10)" width="2" x="9" y="-2"></rect><rect height="24" rx="1" transform="rotate(-45 10 10)" width="2" x="9" y="-2"></rect></g></svg>
# <div class="search-options">
# <div class="dropdown-legacy left-bar">
# <div class="displayed-item">
# <span>
# 			Location
# 		</span>
# <svg aria-labelledby="chevronSVG" class="icon-chevron arrow" height="6" role="img" viewbox="0 0 10 6" width="10" xmlns="http://www.w3.org/2000/svg">
# <title id="chevronSVG">Chevron down</title>
# <path d="M10 .969L9.037 0 5 4.063.963 0 0 .969 5 6z"></path>
# </svg>
# </div>
# <div class="items">
# <a class="item active" value="/en/search-locations">
# <span>Location</span>
# <svg alt="" class="item-icon icon-check" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M7.832 17.496L2.142 11.9.205 13.792l7.627 7.503L24.205 5.188l-1.924-1.893z"></path><use fill="#000" fill-rule="evenodd"></use></svg>
# </a>
# <a class="item" value="/en/search-news">
# <span>News</span>
# <svg alt="" class="item-icon icon-check" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M7.832 17.496L2.142 11.9.205 13.792l7.627 7.503L24.205 5.188l-1.924-1.893z"></path><use fill="#000" fill-rule="evenodd"></use></svg>
# </a>
# <a class="item" value="/en/search-video">
# <span>Videos</span>
# <svg alt="" class="item-icon icon-check" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M7.832 17.496L2.142 11.9.205 13.792l7.627 7.503L24.205 5.188l-1.924-1.893z"></path><use fill="#000" fill-rule="evenodd"></use></svg>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="search-bar-dropdown">
# <div class="use-current-location">
# <svg class="icon-gps gps-icon" height="16" viewbox="0 0 14 18" width="14" xmlns="http://www.w3.org/2000/svg"><g fill-opacity="0.995941" fill-rule="evenodd" id="Symbols" stroke="none" stroke-width="1"><g id="ICONS-/-Menu-/-GPS"><polygon id="Triangle" points="9.44615242 -1.13878407 15.4461524 15.8612159 9.44615242 12.4612159 3.44615242 15.8612159" transform="translate(9.446152, 7.361216) rotate(-330.000000) translate(-9.446152, -7.361216) "></polygon></g></g></svg>
# <span>Use Current Location</span>
# </div>
# <div class="recent-locations-dropdown">
# <div class="recent-title">Recent</div>
# <a class="recent-location" data-fetch="false" data-location-key="222191" href="/web-api/three-day-redirect?key=222191&amp;target=">
# <div class="recent-location__title-wrapper">
# <p class="recent-location__name">Almaty</p>
# <p class="recent-location__admin">Almaty</p>
# </div>
# <svg class="recent-location__icon" data-src="/images/weathericons/18.svg" height="32" viewbox="0 0 288 288" width="32"><g fill="none" fill-rule="evenodd" stroke-width="9.796"><path d="M204.873 168.698c31.109 0 56.327-25.218 56.327-56.327 0-31.108-25.218-56.326-56.327-56.326h-9.649c-17.997-21.189-47.006-29.414-73.446-20.826-26.44 8.588-45.079 32.29-47.19 60.01H62.784c-20.288 0-36.735 16.446-36.735 36.734s16.447 36.735 36.735 36.735h142.09Z" stroke="#BABABA"></path><path d="m50.44 234.429 26.842-45.992M121.657 234.429l26.841-45.992M72.53 257.645l40.36-69.208M194.294 234.429l26.84-45.992M145.118 257.645l40.409-69.208" stroke="#288ADB"></path></g></svg>
# <span class="recent-location__temp">7°</span>
# </a>
# </div>
# <div class="search-results">
# <div class="results-container"></div>
# </div>
# <div class="search-results no-search-result hidden">
# <div class="results-container">
# <div class="search-bar-result search-result no-result">
# <div class="no-result-headline">No results found.</div>
# <div class="no-result-text">Try searching for a city, zip code or point of interest.</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <svg class="hamburger-button icon-hamburger" data-qa="navigationMenu" height="18" viewbox="0 0 24 24" width="18" xmlns="http://www.w3.org/2000/svg">
# <defs>
# <path d="M10 12v1H0v-1h10zm6-6v1H0V6h16zm0-6v1H0V0h16z" id="svghamburger"></path>
# </defs>
# <use fill="#FFF" fill-rule="evenodd" transform="matrix(-1 0 0 1 20 6)" xlink:href="#svghamburger"></use></svg>
# <svg class="close-button close-icon" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><g fill-rule="evenodd" transform="translate(-1 -1)"><rect height="24" rx="1" transform="rotate(45 10 10)" width="2" x="9" y="-2"></rect><rect height="24" rx="1" transform="rotate(-45 10 10)" width="2" x="9" y="-2"></rect></g></svg>
# </div>
# </div>
# </div>
# <div class="header-menu">
# <div class="settings-link">
# <a href="/en/settings">
# <svg class="icon-settings" fill="#FFF" height="25" viewbox="0 0 24 25" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M13.677.107l.871 2.674c.775.225 1.549.483 2.162.902l2.58-1.32 2.452 2.447-1.29 2.578c.354.612.645 1.353.87 2.094l2.678.902v3.414l-2.645.838c-.258.773-.549 1.578-.903 2.255l1.29 2.48-2.452 2.449-2.58-1.224c-.645.386-1.387.676-2.162.902l-.87 2.609h-3.42l-.903-2.61c-.742-.225-1.484-.482-2.161-.934L4.742 21.82 2.29 19.372l1.29-2.449c-.386-.676-.677-1.45-.903-2.255L0 13.798v-3.447l2.71-.902c.193-.74.451-1.481.87-2.094L2.29 4.843l2.452-2.449 2.452 1.289c.677-.387 1.419-.677 2.16-.902l.904-2.674h3.42zm-.838 1.128h-1.807l-.806 2.448-.549.193c-.677.194-1.354.419-1.935.773l-.548.29-2.29-1.16L3.58 5.1l1.225 2.384-.354.548c-.323.483-.581 1.127-.71 1.74l-.13.612-2.515.805v1.804l2.451.805.194.58c.193.677.42 1.385.774 1.965l.29.548-1.16 2.287L4.967 20.5l2.322-1.16.549.355c.58.354 1.226.612 1.903.773l.548.193.775 2.32h1.838l.774-2.417.581-.128c.677-.194 1.323-.42 1.903-.741l.484-.322 2.42 1.127 1.322-1.32-1.161-2.288.29-.483c.323-.645.58-1.353.774-2.062l.194-.58 2.42-.74V11.19l-2.452-.805-.194-.548c-.193-.677-.42-1.32-.742-1.836l-.29-.548 1.161-2.384-1.322-1.353-2.388 1.256-.548-.354a7.5 7.5 0 00-1.903-.74l-.58-.194-.807-2.448zm-.871 5.38c3.032 0 5.548 2.448 5.548 5.508 0 3.028-2.516 5.541-5.548 5.541-3.065 0-5.516-2.545-5.516-5.54a5.49 5.49 0 015.516-5.51zm0 1.063c-2.323 0-4.355 2.093-4.355 4.445 0 2.352 2.032 4.446 4.355 4.446 2.322 0 4.387-2.126 4.387-4.446 0-2.352-2.065-4.445-4.387-4.445z"></path></svg>
# 				settings
# 			</a>
# <svg class="close-button close-icon" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><g fill-rule="evenodd" transform="translate(-1 -1)"><rect height="24" rx="1" transform="rotate(45 10 10)" width="2" x="9" y="-2"></rect><rect height="24" rx="1" transform="rotate(-45 10 10)" width="2" x="9" y="-2"></rect></g></svg>
# </div>
# <div class="header-loc-weather">Almaty, Almaty Weather</div>
# <a class="header-link active" data-page-id="today" href="/en/kz/almaty/222191/weather-forecast/222191">Today</a>
# <a class="header-link nav-red-dot hidden tropical-link" data-page-id="local_{stormName}_tracker" href="/en/kz/almaty/222191/tropical-weather-forecast/222191?eventkey={eventkey}">Local {stormName} Tracker</a>
# <a class="header-link" data-page-id="hourly" href="/en/kz/almaty/222191/hourly-weather-forecast/222191">Hourly</a>
# <a class="header-link" data-page-id="daily" href="/en/kz/almaty/222191/daily-weather-forecast/222191">Daily</a>
# <a class="header-link" data-page-id="radar" href="/en/kz/almaty/222191/weather-radar/222191">Radar</a>
# <a class="header-link" data-page-id="minutecast" href="/en/kz/almaty/222191/minute-weather-forecast/222191">MinuteCast</a>
# <a class="header-link" data-page-id="monthly" href="/en/kz/almaty/222191/october-weather/222191">Monthly</a>
# <a class="header-link" data-page-id="air_quality" href="/en/kz/almaty/222191/air-quality-index/222191">Air Quality</a>
# <a class="header-link" data-page-id="health_and_activities" href="/en/kz/almaty/222191/health-activities/222191">Health &amp; Activities</a>
# <div class="more-cta-links">
# <h2 class="more-cta-title">
# 		Around the Globe
# 	</h2>
# <a class="cta-link" data-page-id="hurricane_tracker" href="/en/hurricane">
# <h3 class="cta-text">Hurricane Tracker</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-page-id="radar_and_maps" href="/en/kz/almaty/weather-radar">
# <h3 class="cta-text">Radar &amp; Maps</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <div class="sublink-container">
# <div class="sublink-header">
# <div class="sublink-title">News</div>
# <svg class="icon-chevron chevron-icon down" height="6" viewbox="0 0 10 6" width="10" xmlns="http://www.w3.org/2000/svg"><path d="M10 .969L9.037 0 5 4.063.963 0 0 .969 5 6z"></path></svg>
# </div>
# <a class="cta-link" data-page-id="news_and_features" href="/en/weather-news">
# <h3 class="cta-text">News &amp; Features</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-page-id="astronomy" href="/en/space-news">
# <h3 class="cta-text">Astronomy</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-page-id="business" href="/en/business">
# <h3 class="cta-text">Business</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-page-id="climate" href="/en/climate">
# <h3 class="cta-text">Climate</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-page-id="health" href="/en/health-wellness">
# <h3 class="cta-text">Health</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-page-id="recreation" href="/en/leisure-recreation">
# <h3 class="cta-text">Recreation</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-page-id="sports" href="/en/sports">
# <h3 class="cta-text">Sports</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-page-id="travel" href="/en/travel">
# <h3 class="cta-text">Travel</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# </div>
# <a class="cta-link" data-page-id="video" href="/en/videos">
# <h3 class="cta-text">Video</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-page-id="podcasts" href="/podcast">
# <h3 class="cta-text">Podcasts</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# </div>
# </div>
# </div>
#
#
# <div class="header-outer">
# <div class="header-inner">
# <a class="header-logo" href="/">
# <svg data-eager="" height="24" viewbox="0 0 189 27" width="168" xmlns="http://www.w3.org/2000/svg"><g fill="none"><path d="M183.058 22.739v-6.864c0-1.4.293-2.342.879-2.83.585-.488 1.561-.716 2.863-.716h1.269v-3.09h-1.074c-.976 0-1.822.13-2.505.422a4.054 4.054 0 0 0-1.66 1.237l-.65-1.66h-2.44v13.5h3.318zM171.28 11.743c.944 0 1.66.26 2.148.814.488.553.748 1.268.813 2.147h-6.117c.065-.911.326-1.627.814-2.147.488-.553 1.204-.814 2.147-.814h.195zm2.766 6.93c-.228.487-.553.878-.976 1.138-.423.293-.944.423-1.627.423h-.228c-1.008 0-1.757-.293-2.277-.846-.52-.553-.814-1.301-.879-2.18h9.469v-1.366c0-2.114-.553-3.806-1.66-5.042-1.106-1.269-2.635-1.887-4.555-1.887h-.228c-1.92 0-3.449.618-4.588 1.887-1.138 1.236-1.692 2.863-1.692 4.847v.878c0 .976.163 1.855.456 2.668a5.877 5.877 0 0 0 1.269 2.082 5.83 5.83 0 0 0 2.017 1.366c.814.325 1.692.488 2.7.488h.229c1.269 0 2.342-.26 3.253-.748s1.66-1.236 2.213-2.245l-2.896-1.464zm-20.271 4.066v-7.873c.033-.91.26-1.659.716-2.244.455-.586 1.139-.879 1.985-.879h.325c.748 0 1.334.228 1.757.716.456.455.65 1.236.65 2.31v8.002h3.32v-8.588c0-1.594-.423-2.863-1.302-3.838-.878-.976-2.017-1.464-3.481-1.464h-.39c-.717 0-1.4.13-2.018.423a5.332 5.332 0 0 0-1.627 1.17V3.84h-3.319v18.9h3.384zm-8.688-2.96c-.227-.196-.325-.554-.325-1.074v-6.799h3.254V9.239h-3.254v-2.96h-2.83l-.359 2.96h-2.212v2.667h2.115v6.831c0 1.236.293 2.212.878 2.928.586.716 1.595 1.074 2.994 1.074h2.635V20.07h-1.92c-.455 0-.78-.098-.976-.293zm-13.828.52c-.683 0-1.204-.13-1.562-.39-.358-.26-.553-.651-.553-1.14v-.097c0-.488.195-.91.618-1.236.39-.325 1.106-.488 2.148-.488h2.472v.488c0 .976-.26 1.692-.78 2.147-.521.456-1.237.716-2.083.716h-.26zm-.65 2.797c.878 0 1.626-.162 2.31-.488.683-.325 1.236-.813 1.691-1.496l.553 1.66h2.506v-8.85c0-1.658-.488-2.927-1.464-3.773-.977-.845-2.343-1.268-4.068-1.268h-.325c-1.562 0-2.798.325-3.71.943-.91.65-1.496 1.431-1.756 2.342l2.928 1.204c.163-.456.456-.813.846-1.139.39-.292.944-.455 1.627-.455h.325c.781 0 1.367.195 1.725.553.39.39.553.91.553 1.594v.683h-2.408c-1.985 0-3.481.39-4.523 1.171-1.04.78-1.561 1.822-1.561 3.09v.196c0 1.268.39 2.244 1.17 2.992.782.716 1.888 1.106 3.32 1.106h.26v-.065zm-12.495-11.353c.943 0 1.659.26 2.147.814.488.553.748 1.268.813 2.147h-6.117c.065-.911.326-1.627.814-2.147.488-.553 1.204-.814 2.147-.814h.196zm2.765 6.93c-.228.487-.553.878-.976 1.138-.423.293-.943.423-1.627.423h-.228c-1.008 0-1.757-.293-2.277-.846-.52-.553-.814-1.301-.879-2.18h9.469v-1.366c0-2.114-.553-3.806-1.66-5.042-1.106-1.269-2.635-1.887-4.555-1.887h-.26c-1.92 0-3.45.618-4.588 1.887-1.139 1.236-1.692 2.863-1.692 4.847v.878c0 .976.163 1.855.455 2.668a5.877 5.877 0 0 0 1.27 2.082 5.83 5.83 0 0 0 2.017 1.366c.813.325 1.692.488 2.7.488h.228c1.27 0 2.343-.26 3.254-.748s1.66-1.236 2.213-2.245l-2.864-1.464zM95.76 22.738l3.97-13.76 3.774 13.76h3.026l5.434-18.673V3.84h-3.254l-3.58 13.37-3.513-13.37h-3.58L94.36 17.436 90.878 3.84h-3.416v.227l5.206 18.673h3.091zm-21.312-13.5v8.555c0 1.594.423 2.863 1.301 3.839.879.975 2.018 1.463 3.482 1.463h.358c.813 0 1.561-.162 2.212-.488.684-.325 1.237-.813 1.692-1.43l.553 1.56h2.473v-13.5h-3.286v7.873c-.033.91-.26 1.659-.748 2.244-.489.586-1.14.879-2.018.879h-.325c-.716 0-1.302-.228-1.757-.716-.456-.455-.684-1.236-.684-2.31V9.206h-3.253v.033zm-3.645.553c-.91-.586-2.082-.879-3.546-.879h-.228c-1.92 0-3.449.553-4.588 1.692-1.139 1.138-1.692 2.635-1.692 4.522v1.724c0 1.886.553 3.415 1.692 4.521 1.139 1.139 2.636 1.692 4.588 1.692h.228c1.334 0 2.44-.26 3.319-.78.878-.521 1.561-1.27 2.082-2.31l-2.733-1.53a3.17 3.17 0 0 1-.976 1.27c-.423.325-.976.487-1.692.487h-.228c-1.041 0-1.79-.325-2.278-.943-.488-.618-.715-1.431-.715-2.44V15.16c0-1.008.227-1.822.715-2.44.488-.618 1.237-.943 2.278-.943h.228c.716 0 1.301.163 1.724.488.423.325.749.78.976 1.334l2.864-1.367c-.423-1.008-1.107-1.854-2.018-2.44zm-13.308 0c-.91-.586-2.082-.879-3.546-.879h-.228c-1.92 0-3.449.553-4.588 1.692-1.139 1.138-1.692 2.635-1.692 4.522v1.724c0 1.886.553 3.415 1.692 4.521 1.139 1.139 2.636 1.692 4.588 1.692h.228c1.334 0 2.44-.26 3 ...
# </a>
# <a class="header-city-link" href="/en/kz/almaty/222191/weather-forecast/222191">
# <h1 class="header-loc">Almaty, Almaty</h1>
# <span class="header-temp">
# 						7°
# 						<span class="unit">C</span>
# </span>
# <svg class="header-weather-icon" data-src="/images/weathericons/18.svg" height="27" viewbox="0 0 288 288" width="27"><g fill="none" fill-rule="evenodd" stroke-width="9.796"><path d="M204.873 168.698c31.109 0 56.327-25.218 56.327-56.327 0-31.108-25.218-56.326-56.327-56.326h-9.649c-17.997-21.189-47.006-29.414-73.446-20.826-26.44 8.588-45.079 32.29-47.19 60.01H62.784c-20.288 0-36.735 16.446-36.735 36.734s16.447 36.735 36.735 36.735h142.09Z" stroke="#BABABA"></path><path d="m50.44 234.429 26.842-45.992M121.657 234.429l26.841-45.992M72.53 257.645l40.36-69.208M194.294 234.429l26.84-45.992M145.118 257.645l40.409-69.208" stroke="#288ADB"></path></g></svg>
# </a>
# <div class="pull-right">
# <div class="header-search-bar search-bar">
# <div class="searchbar-inner">
# <svg class="icon-search" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M7.186 13.554c-3.462 0-6.303-2.869-6.303-6.359C.883 3.681 3.724.837 7.186.837c3.437 0 6.278 2.844 6.278 6.358 0 3.49-2.865 6.359-6.278 6.359zm5.323-1.602a7.176 7.176 0 0 0 1.815-4.757c0-3.968-3.2-7.195-7.138-7.195C3.223 0 0 3.227 0 7.195c0 3.944 3.223 7.171 7.186 7.171a7.058 7.058 0 0 0 4.75-1.84L17.427 18l.573-.55-5.49-5.498z" transform="translate(3 3)"></path></svg>
# <form action="/en/search-locations" class="search-form" method="GET">
# <input autocomplete="off" class="search-input" name="query" placeholder="Search" type="text"/>
# </form>
# <svg class="clear-icon close-icon" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><g fill-rule="evenodd" transform="translate(-1 -1)"><rect height="24" rx="1" transform="rotate(45 10 10)" width="2" x="9" y="-2"></rect><rect height="24" rx="1" transform="rotate(-45 10 10)" width="2" x="9" y="-2"></rect></g></svg>
# <div class="search-options">
# <div class="dropdown-legacy left-bar">
# <div class="displayed-item">
# <span>
# 			Location
# 		</span>
# <svg aria-labelledby="chevronSVG" class="icon-chevron arrow" height="6" role="img" viewbox="0 0 10 6" width="10" xmlns="http://www.w3.org/2000/svg">
# <title id="chevronSVG">Chevron down</title>
# <path d="M10 .969L9.037 0 5 4.063.963 0 0 .969 5 6z"></path>
# </svg>
# </div>
# <div class="items">
# <a class="item active" value="/en/search-locations">
# <span>Location</span>
# <svg alt="" class="item-icon icon-check" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M7.832 17.496L2.142 11.9.205 13.792l7.627 7.503L24.205 5.188l-1.924-1.893z"></path><use fill="#000" fill-rule="evenodd"></use></svg>
# </a>
# <a class="item" value="/en/search-news">
# <span>News</span>
# <svg alt="" class="item-icon icon-check" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M7.832 17.496L2.142 11.9.205 13.792l7.627 7.503L24.205 5.188l-1.924-1.893z"></path><use fill="#000" fill-rule="evenodd"></use></svg>
# </a>
# <a class="item" value="/en/search-video">
# <span>Videos</span>
# <svg alt="" class="item-icon icon-check" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M7.832 17.496L2.142 11.9.205 13.792l7.627 7.503L24.205 5.188l-1.924-1.893z"></path><use fill="#000" fill-rule="evenodd"></use></svg>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="search-bar-dropdown">
# <div class="use-current-location">
# <svg class="icon-gps gps-icon" height="16" viewbox="0 0 14 18" width="14" xmlns="http://www.w3.org/2000/svg"><g fill-opacity="0.995941" fill-rule="evenodd" id="Symbols" stroke="none" stroke-width="1"><g id="ICONS-/-Menu-/-GPS"><polygon id="Triangle" points="9.44615242 -1.13878407 15.4461524 15.8612159 9.44615242 12.4612159 3.44615242 15.8612159" transform="translate(9.446152, 7.361216) rotate(-330.000000) translate(-9.446152, -7.361216) "></polygon></g></g></svg>
# <span>Use Current Location</span>
# </div>
# <div class="recent-locations-dropdown">
# <div class="recent-title">Recent</div>
# <a class="recent-location" data-fetch="false" data-location-key="222191" href="/web-api/three-day-redirect?key=222191&amp;target=">
# <div class="recent-location__title-wrapper">
# <p class="recent-location__name">Almaty</p>
# <p class="recent-location__admin">Almaty</p>
# </div>
# <svg class="recent-location__icon" data-src="/images/weathericons/18.svg" height="32" viewbox="0 0 288 288" width="32"><g fill="none" fill-rule="evenodd" stroke-width="9.796"><path d="M204.873 168.698c31.109 0 56.327-25.218 56.327-56.327 0-31.108-25.218-56.326-56.327-56.326h-9.649c-17.997-21.189-47.006-29.414-73.446-20.826-26.44 8.588-45.079 32.29-47.19 60.01H62.784c-20.288 0-36.735 16.446-36.735 36.734s16.447 36.735 36.735 36.735h142.09Z" stroke="#BABABA"></path><path d="m50.44 234.429 26.842-45.992M121.657 234.429l26.841-45.992M72.53 257.645l40.36-69.208M194.294 234.429l26.84-45.992M145.118 257.645l40.409-69.208" stroke="#288ADB"></path></g></svg>
# <span class="recent-location__temp">7°</span>
# </a>
# </div>
# <div class="search-results">
# <div class="results-container"></div>
# </div>
# <div class="search-results no-search-result hidden">
# <div class="results-container">
# <div class="search-bar-result search-result no-result">
# <div class="no-result-headline">No results found.</div>
# <div class="no-result-text">Try searching for a city, zip code or point of interest.</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <svg class="hamburger-button icon-hamburger" data-qa="navigationMenu" height="18" viewbox="0 0 24 24" width="18" xmlns="http://www.w3.org/2000/svg">
# <defs>
# <path d="M10 12v1H0v-1h10zm6-6v1H0V6h16zm0-6v1H0V0h16z" id="svghamburger"></path>
# </defs>
# <use fill="#FFF" fill-rule="evenodd" transform="matrix(-1 0 0 1 20 6)" xlink:href="#svghamburger"></use></svg>
# <svg class="close-button close-icon" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><g fill-rule="evenodd" transform="translate(-1 -1)"><rect height="24" rx="1" transform="rotate(45 10 10)" width="2" x="9" y="-2"></rect><rect height="24" rx="1" transform="rotate(-45 10 10)" width="2" x="9" y="-2"></rect></g></svg>
# </div>
# </div>
# </div>
#
#
# <div class="header-inner">
# <a class="header-logo" href="/">
# <svg data-eager="" height="24" viewbox="0 0 189 27" width="168" xmlns="http://www.w3.org/2000/svg"><g fill="none"><path d="M183.058 22.739v-6.864c0-1.4.293-2.342.879-2.83.585-.488 1.561-.716 2.863-.716h1.269v-3.09h-1.074c-.976 0-1.822.13-2.505.422a4.054 4.054 0 0 0-1.66 1.237l-.65-1.66h-2.44v13.5h3.318zM171.28 11.743c.944 0 1.66.26 2.148.814.488.553.748 1.268.813 2.147h-6.117c.065-.911.326-1.627.814-2.147.488-.553 1.204-.814 2.147-.814h.195zm2.766 6.93c-.228.487-.553.878-.976 1.138-.423.293-.944.423-1.627.423h-.228c-1.008 0-1.757-.293-2.277-.846-.52-.553-.814-1.301-.879-2.18h9.469v-1.366c0-2.114-.553-3.806-1.66-5.042-1.106-1.269-2.635-1.887-4.555-1.887h-.228c-1.92 0-3.449.618-4.588 1.887-1.138 1.236-1.692 2.863-1.692 4.847v.878c0 .976.163 1.855.456 2.668a5.877 5.877 0 0 0 1.269 2.082 5.83 5.83 0 0 0 2.017 1.366c.814.325 1.692.488 2.7.488h.229c1.269 0 2.342-.26 3.253-.748s1.66-1.236 2.213-2.245l-2.896-1.464zm-20.271 4.066v-7.873c.033-.91.26-1.659.716-2.244.455-.586 1.139-.879 1.985-.879h.325c.748 0 1.334.228 1.757.716.456.455.65 1.236.65 2.31v8.002h3.32v-8.588c0-1.594-.423-2.863-1.302-3.838-.878-.976-2.017-1.464-3.481-1.464h-.39c-.717 0-1.4.13-2.018.423a5.332 5.332 0 0 0-1.627 1.17V3.84h-3.319v18.9h3.384zm-8.688-2.96c-.227-.196-.325-.554-.325-1.074v-6.799h3.254V9.239h-3.254v-2.96h-2.83l-.359 2.96h-2.212v2.667h2.115v6.831c0 1.236.293 2.212.878 2.928.586.716 1.595 1.074 2.994 1.074h2.635V20.07h-1.92c-.455 0-.78-.098-.976-.293zm-13.828.52c-.683 0-1.204-.13-1.562-.39-.358-.26-.553-.651-.553-1.14v-.097c0-.488.195-.91.618-1.236.39-.325 1.106-.488 2.148-.488h2.472v.488c0 .976-.26 1.692-.78 2.147-.521.456-1.237.716-2.083.716h-.26zm-.65 2.797c.878 0 1.626-.162 2.31-.488.683-.325 1.236-.813 1.691-1.496l.553 1.66h2.506v-8.85c0-1.658-.488-2.927-1.464-3.773-.977-.845-2.343-1.268-4.068-1.268h-.325c-1.562 0-2.798.325-3.71.943-.91.65-1.496 1.431-1.756 2.342l2.928 1.204c.163-.456.456-.813.846-1.139.39-.292.944-.455 1.627-.455h.325c.781 0 1.367.195 1.725.553.39.39.553.91.553 1.594v.683h-2.408c-1.985 0-3.481.39-4.523 1.171-1.04.78-1.561 1.822-1.561 3.09v.196c0 1.268.39 2.244 1.17 2.992.782.716 1.888 1.106 3.32 1.106h.26v-.065zm-12.495-11.353c.943 0 1.659.26 2.147.814.488.553.748 1.268.813 2.147h-6.117c.065-.911.326-1.627.814-2.147.488-.553 1.204-.814 2.147-.814h.196zm2.765 6.93c-.228.487-.553.878-.976 1.138-.423.293-.943.423-1.627.423h-.228c-1.008 0-1.757-.293-2.277-.846-.52-.553-.814-1.301-.879-2.18h9.469v-1.366c0-2.114-.553-3.806-1.66-5.042-1.106-1.269-2.635-1.887-4.555-1.887h-.26c-1.92 0-3.45.618-4.588 1.887-1.139 1.236-1.692 2.863-1.692 4.847v.878c0 .976.163 1.855.455 2.668a5.877 5.877 0 0 0 1.27 2.082 5.83 5.83 0 0 0 2.017 1.366c.813.325 1.692.488 2.7.488h.228c1.27 0 2.343-.26 3.254-.748s1.66-1.236 2.213-2.245l-2.864-1.464zM95.76 22.738l3.97-13.76 3.774 13.76h3.026l5.434-18.673V3.84h-3.254l-3.58 13.37-3.513-13.37h-3.58L94.36 17.436 90.878 3.84h-3.416v.227l5.206 18.673h3.091zm-21.312-13.5v8.555c0 1.594.423 2.863 1.301 3.839.879.975 2.018 1.463 3.482 1.463h.358c.813 0 1.561-.162 2.212-.488.684-.325 1.237-.813 1.692-1.43l.553 1.56h2.473v-13.5h-3.286v7.873c-.033.91-.26 1.659-.748 2.244-.489.586-1.14.879-2.018.879h-.325c-.716 0-1.302-.228-1.757-.716-.456-.455-.684-1.236-.684-2.31V9.206h-3.253v.033zm-3.645.553c-.91-.586-2.082-.879-3.546-.879h-.228c-1.92 0-3.449.553-4.588 1.692-1.139 1.138-1.692 2.635-1.692 4.522v1.724c0 1.886.553 3.415 1.692 4.521 1.139 1.139 2.636 1.692 4.588 1.692h.228c1.334 0 2.44-.26 3.319-.78.878-.521 1.561-1.27 2.082-2.31l-2.733-1.53a3.17 3.17 0 0 1-.976 1.27c-.423.325-.976.487-1.692.487h-.228c-1.041 0-1.79-.325-2.278-.943-.488-.618-.715-1.431-.715-2.44V15.16c0-1.008.227-1.822.715-2.44.488-.618 1.237-.943 2.278-.943h.228c.716 0 1.301.163 1.724.488.423.325.749.78.976 1.334l2.864-1.367c-.423-1.008-1.107-1.854-2.018-2.44zm-13.308 0c-.91-.586-2.082-.879-3.546-.879h-.228c-1.92 0-3.449.553-4.588 1.692-1.139 1.138-1.692 2.635-1.692 4.522v1.724c0 1.886.553 3.415 1.692 4.521 1.139 1.139 2.636 1.692 4.588 1.692h.228c1.334 0 2.44-.26 3 ...
# </a>
# <a class="header-city-link" href="/en/kz/almaty/222191/weather-forecast/222191">
# <h1 class="header-loc">Almaty, Almaty</h1>
# <span class="header-temp">
# 						7°
# 						<span class="unit">C</span>
# </span>
# <svg class="header-weather-icon" data-src="/images/weathericons/18.svg" height="27" viewbox="0 0 288 288" width="27"><g fill="none" fill-rule="evenodd" stroke-width="9.796"><path d="M204.873 168.698c31.109 0 56.327-25.218 56.327-56.327 0-31.108-25.218-56.326-56.327-56.326h-9.649c-17.997-21.189-47.006-29.414-73.446-20.826-26.44 8.588-45.079 32.29-47.19 60.01H62.784c-20.288 0-36.735 16.446-36.735 36.734s16.447 36.735 36.735 36.735h142.09Z" stroke="#BABABA"></path><path d="m50.44 234.429 26.842-45.992M121.657 234.429l26.841-45.992M72.53 257.645l40.36-69.208M194.294 234.429l26.84-45.992M145.118 257.645l40.409-69.208" stroke="#288ADB"></path></g></svg>
# </a>
# <div class="pull-right">
# <div class="header-search-bar search-bar">
# <div class="searchbar-inner">
# <svg class="icon-search" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M7.186 13.554c-3.462 0-6.303-2.869-6.303-6.359C.883 3.681 3.724.837 7.186.837c3.437 0 6.278 2.844 6.278 6.358 0 3.49-2.865 6.359-6.278 6.359zm5.323-1.602a7.176 7.176 0 0 0 1.815-4.757c0-3.968-3.2-7.195-7.138-7.195C3.223 0 0 3.227 0 7.195c0 3.944 3.223 7.171 7.186 7.171a7.058 7.058 0 0 0 4.75-1.84L17.427 18l.573-.55-5.49-5.498z" transform="translate(3 3)"></path></svg>
# <form action="/en/search-locations" class="search-form" method="GET">
# <input autocomplete="off" class="search-input" name="query" placeholder="Search" type="text"/>
# </form>
# <svg class="clear-icon close-icon" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><g fill-rule="evenodd" transform="translate(-1 -1)"><rect height="24" rx="1" transform="rotate(45 10 10)" width="2" x="9" y="-2"></rect><rect height="24" rx="1" transform="rotate(-45 10 10)" width="2" x="9" y="-2"></rect></g></svg>
# <div class="search-options">
# <div class="dropdown-legacy left-bar">
# <div class="displayed-item">
# <span>
# 			Location
# 		</span>
# <svg aria-labelledby="chevronSVG" class="icon-chevron arrow" height="6" role="img" viewbox="0 0 10 6" width="10" xmlns="http://www.w3.org/2000/svg">
# <title id="chevronSVG">Chevron down</title>
# <path d="M10 .969L9.037 0 5 4.063.963 0 0 .969 5 6z"></path>
# </svg>
# </div>
# <div class="items">
# <a class="item active" value="/en/search-locations">
# <span>Location</span>
# <svg alt="" class="item-icon icon-check" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M7.832 17.496L2.142 11.9.205 13.792l7.627 7.503L24.205 5.188l-1.924-1.893z"></path><use fill="#000" fill-rule="evenodd"></use></svg>
# </a>
# <a class="item" value="/en/search-news">
# <span>News</span>
# <svg alt="" class="item-icon icon-check" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M7.832 17.496L2.142 11.9.205 13.792l7.627 7.503L24.205 5.188l-1.924-1.893z"></path><use fill="#000" fill-rule="evenodd"></use></svg>
# </a>
# <a class="item" value="/en/search-video">
# <span>Videos</span>
# <svg alt="" class="item-icon icon-check" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M7.832 17.496L2.142 11.9.205 13.792l7.627 7.503L24.205 5.188l-1.924-1.893z"></path><use fill="#000" fill-rule="evenodd"></use></svg>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="search-bar-dropdown">
# <div class="use-current-location">
# <svg class="icon-gps gps-icon" height="16" viewbox="0 0 14 18" width="14" xmlns="http://www.w3.org/2000/svg"><g fill-opacity="0.995941" fill-rule="evenodd" id="Symbols" stroke="none" stroke-width="1"><g id="ICONS-/-Menu-/-GPS"><polygon id="Triangle" points="9.44615242 -1.13878407 15.4461524 15.8612159 9.44615242 12.4612159 3.44615242 15.8612159" transform="translate(9.446152, 7.361216) rotate(-330.000000) translate(-9.446152, -7.361216) "></polygon></g></g></svg>
# <span>Use Current Location</span>
# </div>
# <div class="recent-locations-dropdown">
# <div class="recent-title">Recent</div>
# <a class="recent-location" data-fetch="false" data-location-key="222191" href="/web-api/three-day-redirect?key=222191&amp;target=">
# <div class="recent-location__title-wrapper">
# <p class="recent-location__name">Almaty</p>
# <p class="recent-location__admin">Almaty</p>
# </div>
# <svg class="recent-location__icon" data-src="/images/weathericons/18.svg" height="32" viewbox="0 0 288 288" width="32"><g fill="none" fill-rule="evenodd" stroke-width="9.796"><path d="M204.873 168.698c31.109 0 56.327-25.218 56.327-56.327 0-31.108-25.218-56.326-56.327-56.326h-9.649c-17.997-21.189-47.006-29.414-73.446-20.826-26.44 8.588-45.079 32.29-47.19 60.01H62.784c-20.288 0-36.735 16.446-36.735 36.734s16.447 36.735 36.735 36.735h142.09Z" stroke="#BABABA"></path><path d="m50.44 234.429 26.842-45.992M121.657 234.429l26.841-45.992M72.53 257.645l40.36-69.208M194.294 234.429l26.84-45.992M145.118 257.645l40.409-69.208" stroke="#288ADB"></path></g></svg>
# <span class="recent-location__temp">7°</span>
# </a>
# </div>
# <div class="search-results">
# <div class="results-container"></div>
# </div>
# <div class="search-results no-search-result hidden">
# <div class="results-container">
# <div class="search-bar-result search-result no-result">
# <div class="no-result-headline">No results found.</div>
# <div class="no-result-text">Try searching for a city, zip code or point of interest.</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <svg class="hamburger-button icon-hamburger" data-qa="navigationMenu" height="18" viewbox="0 0 24 24" width="18" xmlns="http://www.w3.org/2000/svg">
# <defs>
# <path d="M10 12v1H0v-1h10zm6-6v1H0V6h16zm0-6v1H0V0h16z" id="svghamburger"></path>
# </defs>
# <use fill="#FFF" fill-rule="evenodd" transform="matrix(-1 0 0 1 20 6)" xlink:href="#svghamburger"></use></svg>
# <svg class="close-button close-icon" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><g fill-rule="evenodd" transform="translate(-1 -1)"><rect height="24" rx="1" transform="rotate(45 10 10)" width="2" x="9" y="-2"></rect><rect height="24" rx="1" transform="rotate(-45 10 10)" width="2" x="9" y="-2"></rect></g></svg>
# </div>
# </div>
#
#
# <a class="header-logo" href="/">
# <svg data-eager="" height="24" viewbox="0 0 189 27" width="168" xmlns="http://www.w3.org/2000/svg"><g fill="none"><path d="M183.058 22.739v-6.864c0-1.4.293-2.342.879-2.83.585-.488 1.561-.716 2.863-.716h1.269v-3.09h-1.074c-.976 0-1.822.13-2.505.422a4.054 4.054 0 0 0-1.66 1.237l-.65-1.66h-2.44v13.5h3.318zM171.28 11.743c.944 0 1.66.26 2.148.814.488.553.748 1.268.813 2.147h-6.117c.065-.911.326-1.627.814-2.147.488-.553 1.204-.814 2.147-.814h.195zm2.766 6.93c-.228.487-.553.878-.976 1.138-.423.293-.944.423-1.627.423h-.228c-1.008 0-1.757-.293-2.277-.846-.52-.553-.814-1.301-.879-2.18h9.469v-1.366c0-2.114-.553-3.806-1.66-5.042-1.106-1.269-2.635-1.887-4.555-1.887h-.228c-1.92 0-3.449.618-4.588 1.887-1.138 1.236-1.692 2.863-1.692 4.847v.878c0 .976.163 1.855.456 2.668a5.877 5.877 0 0 0 1.269 2.082 5.83 5.83 0 0 0 2.017 1.366c.814.325 1.692.488 2.7.488h.229c1.269 0 2.342-.26 3.253-.748s1.66-1.236 2.213-2.245l-2.896-1.464zm-20.271 4.066v-7.873c.033-.91.26-1.659.716-2.244.455-.586 1.139-.879 1.985-.879h.325c.748 0 1.334.228 1.757.716.456.455.65 1.236.65 2.31v8.002h3.32v-8.588c0-1.594-.423-2.863-1.302-3.838-.878-.976-2.017-1.464-3.481-1.464h-.39c-.717 0-1.4.13-2.018.423a5.332 5.332 0 0 0-1.627 1.17V3.84h-3.319v18.9h3.384zm-8.688-2.96c-.227-.196-.325-.554-.325-1.074v-6.799h3.254V9.239h-3.254v-2.96h-2.83l-.359 2.96h-2.212v2.667h2.115v6.831c0 1.236.293 2.212.878 2.928.586.716 1.595 1.074 2.994 1.074h2.635V20.07h-1.92c-.455 0-.78-.098-.976-.293zm-13.828.52c-.683 0-1.204-.13-1.562-.39-.358-.26-.553-.651-.553-1.14v-.097c0-.488.195-.91.618-1.236.39-.325 1.106-.488 2.148-.488h2.472v.488c0 .976-.26 1.692-.78 2.147-.521.456-1.237.716-2.083.716h-.26zm-.65 2.797c.878 0 1.626-.162 2.31-.488.683-.325 1.236-.813 1.691-1.496l.553 1.66h2.506v-8.85c0-1.658-.488-2.927-1.464-3.773-.977-.845-2.343-1.268-4.068-1.268h-.325c-1.562 0-2.798.325-3.71.943-.91.65-1.496 1.431-1.756 2.342l2.928 1.204c.163-.456.456-.813.846-1.139.39-.292.944-.455 1.627-.455h.325c.781 0 1.367.195 1.725.553.39.39.553.91.553 1.594v.683h-2.408c-1.985 0-3.481.39-4.523 1.171-1.04.78-1.561 1.822-1.561 3.09v.196c0 1.268.39 2.244 1.17 2.992.782.716 1.888 1.106 3.32 1.106h.26v-.065zm-12.495-11.353c.943 0 1.659.26 2.147.814.488.553.748 1.268.813 2.147h-6.117c.065-.911.326-1.627.814-2.147.488-.553 1.204-.814 2.147-.814h.196zm2.765 6.93c-.228.487-.553.878-.976 1.138-.423.293-.943.423-1.627.423h-.228c-1.008 0-1.757-.293-2.277-.846-.52-.553-.814-1.301-.879-2.18h9.469v-1.366c0-2.114-.553-3.806-1.66-5.042-1.106-1.269-2.635-1.887-4.555-1.887h-.26c-1.92 0-3.45.618-4.588 1.887-1.139 1.236-1.692 2.863-1.692 4.847v.878c0 .976.163 1.855.455 2.668a5.877 5.877 0 0 0 1.27 2.082 5.83 5.83 0 0 0 2.017 1.366c.813.325 1.692.488 2.7.488h.228c1.27 0 2.343-.26 3.254-.748s1.66-1.236 2.213-2.245l-2.864-1.464zM95.76 22.738l3.97-13.76 3.774 13.76h3.026l5.434-18.673V3.84h-3.254l-3.58 13.37-3.513-13.37h-3.58L94.36 17.436 90.878 3.84h-3.416v.227l5.206 18.673h3.091zm-21.312-13.5v8.555c0 1.594.423 2.863 1.301 3.839.879.975 2.018 1.463 3.482 1.463h.358c.813 0 1.561-.162 2.212-.488.684-.325 1.237-.813 1.692-1.43l.553 1.56h2.473v-13.5h-3.286v7.873c-.033.91-.26 1.659-.748 2.244-.489.586-1.14.879-2.018.879h-.325c-.716 0-1.302-.228-1.757-.716-.456-.455-.684-1.236-.684-2.31V9.206h-3.253v.033zm-3.645.553c-.91-.586-2.082-.879-3.546-.879h-.228c-1.92 0-3.449.553-4.588 1.692-1.139 1.138-1.692 2.635-1.692 4.522v1.724c0 1.886.553 3.415 1.692 4.521 1.139 1.139 2.636 1.692 4.588 1.692h.228c1.334 0 2.44-.26 3.319-.78.878-.521 1.561-1.27 2.082-2.31l-2.733-1.53a3.17 3.17 0 0 1-.976 1.27c-.423.325-.976.487-1.692.487h-.228c-1.041 0-1.79-.325-2.278-.943-.488-.618-.715-1.431-.715-2.44V15.16c0-1.008.227-1.822.715-2.44.488-.618 1.237-.943 2.278-.943h.228c.716 0 1.301.163 1.724.488.423.325.749.78.976 1.334l2.864-1.367c-.423-1.008-1.107-1.854-2.018-2.44zm-13.308 0c-.91-.586-2.082-.879-3.546-.879h-.228c-1.92 0-3.449.553-4.588 1.692-1.139 1.138-1.692 2.635-1.692 4.522v1.724c0 1.886.553 3.415 1.692 4.521 1.139 1.139 2.636 1.692 4.588 1.692h.228c1.334 0 2.44-.26 3 ...
# </a>
#
#
# <svg data-eager="" height="24" viewbox="0 0 189 27" width="168" xmlns="http://www.w3.org/2000/svg"><g fill="none"><path d="M183.058 22.739v-6.864c0-1.4.293-2.342.879-2.83.585-.488 1.561-.716 2.863-.716h1.269v-3.09h-1.074c-.976 0-1.822.13-2.505.422a4.054 4.054 0 0 0-1.66 1.237l-.65-1.66h-2.44v13.5h3.318zM171.28 11.743c.944 0 1.66.26 2.148.814.488.553.748 1.268.813 2.147h-6.117c.065-.911.326-1.627.814-2.147.488-.553 1.204-.814 2.147-.814h.195zm2.766 6.93c-.228.487-.553.878-.976 1.138-.423.293-.944.423-1.627.423h-.228c-1.008 0-1.757-.293-2.277-.846-.52-.553-.814-1.301-.879-2.18h9.469v-1.366c0-2.114-.553-3.806-1.66-5.042-1.106-1.269-2.635-1.887-4.555-1.887h-.228c-1.92 0-3.449.618-4.588 1.887-1.138 1.236-1.692 2.863-1.692 4.847v.878c0 .976.163 1.855.456 2.668a5.877 5.877 0 0 0 1.269 2.082 5.83 5.83 0 0 0 2.017 1.366c.814.325 1.692.488 2.7.488h.229c1.269 0 2.342-.26 3.253-.748s1.66-1.236 2.213-2.245l-2.896-1.464zm-20.271 4.066v-7.873c.033-.91.26-1.659.716-2.244.455-.586 1.139-.879 1.985-.879h.325c.748 0 1.334.228 1.757.716.456.455.65 1.236.65 2.31v8.002h3.32v-8.588c0-1.594-.423-2.863-1.302-3.838-.878-.976-2.017-1.464-3.481-1.464h-.39c-.717 0-1.4.13-2.018.423a5.332 5.332 0 0 0-1.627 1.17V3.84h-3.319v18.9h3.384zm-8.688-2.96c-.227-.196-.325-.554-.325-1.074v-6.799h3.254V9.239h-3.254v-2.96h-2.83l-.359 2.96h-2.212v2.667h2.115v6.831c0 1.236.293 2.212.878 2.928.586.716 1.595 1.074 2.994 1.074h2.635V20.07h-1.92c-.455 0-.78-.098-.976-.293zm-13.828.52c-.683 0-1.204-.13-1.562-.39-.358-.26-.553-.651-.553-1.14v-.097c0-.488.195-.91.618-1.236.39-.325 1.106-.488 2.148-.488h2.472v.488c0 .976-.26 1.692-.78 2.147-.521.456-1.237.716-2.083.716h-.26zm-.65 2.797c.878 0 1.626-.162 2.31-.488.683-.325 1.236-.813 1.691-1.496l.553 1.66h2.506v-8.85c0-1.658-.488-2.927-1.464-3.773-.977-.845-2.343-1.268-4.068-1.268h-.325c-1.562 0-2.798.325-3.71.943-.91.65-1.496 1.431-1.756 2.342l2.928 1.204c.163-.456.456-.813.846-1.139.39-.292.944-.455 1.627-.455h.325c.781 0 1.367.195 1.725.553.39.39.553.91.553 1.594v.683h-2.408c-1.985 0-3.481.39-4.523 1.171-1.04.78-1.561 1.822-1.561 3.09v.196c0 1.268.39 2.244 1.17 2.992.782.716 1.888 1.106 3.32 1.106h.26v-.065zm-12.495-11.353c.943 0 1.659.26 2.147.814.488.553.748 1.268.813 2.147h-6.117c.065-.911.326-1.627.814-2.147.488-.553 1.204-.814 2.147-.814h.196zm2.765 6.93c-.228.487-.553.878-.976 1.138-.423.293-.943.423-1.627.423h-.228c-1.008 0-1.757-.293-2.277-.846-.52-.553-.814-1.301-.879-2.18h9.469v-1.366c0-2.114-.553-3.806-1.66-5.042-1.106-1.269-2.635-1.887-4.555-1.887h-.26c-1.92 0-3.45.618-4.588 1.887-1.139 1.236-1.692 2.863-1.692 4.847v.878c0 .976.163 1.855.455 2.668a5.877 5.877 0 0 0 1.27 2.082 5.83 5.83 0 0 0 2.017 1.366c.813.325 1.692.488 2.7.488h.228c1.27 0 2.343-.26 3.254-.748s1.66-1.236 2.213-2.245l-2.864-1.464zM95.76 22.738l3.97-13.76 3.774 13.76h3.026l5.434-18.673V3.84h-3.254l-3.58 13.37-3.513-13.37h-3.58L94.36 17.436 90.878 3.84h-3.416v.227l5.206 18.673h3.091zm-21.312-13.5v8.555c0 1.594.423 2.863 1.301 3.839.879.975 2.018 1.463 3.482 1.463h.358c.813 0 1.561-.162 2.212-.488.684-.325 1.237-.813 1.692-1.43l.553 1.56h2.473v-13.5h-3.286v7.873c-.033.91-.26 1.659-.748 2.244-.489.586-1.14.879-2.018.879h-.325c-.716 0-1.302-.228-1.757-.716-.456-.455-.684-1.236-.684-2.31V9.206h-3.253v.033zm-3.645.553c-.91-.586-2.082-.879-3.546-.879h-.228c-1.92 0-3.449.553-4.588 1.692-1.139 1.138-1.692 2.635-1.692 4.522v1.724c0 1.886.553 3.415 1.692 4.521 1.139 1.139 2.636 1.692 4.588 1.692h.228c1.334 0 2.44-.26 3.319-.78.878-.521 1.561-1.27 2.082-2.31l-2.733-1.53a3.17 3.17 0 0 1-.976 1.27c-.423.325-.976.487-1.692.487h-.228c-1.041 0-1.79-.325-2.278-.943-.488-.618-.715-1.431-.715-2.44V15.16c0-1.008.227-1.822.715-2.44.488-.618 1.237-.943 2.278-.943h.228c.716 0 1.301.163 1.724.488.423.325.749.78.976 1.334l2.864-1.367c-.423-1.008-1.107-1.854-2.018-2.44zm-13.308 0c-.91-.586-2.082-.879-3.546-.879h-.228c-1.92 0-3.449.553-4.588 1.692-1.139 1.138-1.692 2.635-1.692 4.522v1.724c0 1.886.553 3.415 1.692 4.521 1.139 1.139 2.636 1.692 4.588 1.692h.228c1.334 0 2.44-.26 3 ...
# ...
# </a>
#
#
# <svg alt="Social Icon" class="social-icon" data-src="/images/socialicons/downloads.svg" height="32" viewbox="0 0 36 36" width="32"><g fill="none" fill-rule="evenodd"><path d="M18 0C8.053 0 0 8.053 0 18s8.053 18 18 18 18-8.053 18-18S27.947 0 18 0Z" fill="#EE5723"></path><path d="M12.88 12.947a7.243 7.243 0 0 1 10.24 0c2.813 2.826 2.827 7.413 0 10.226-2.827 2.827-7.413 2.827-10.227 0-2.826-2.813-2.826-7.4-.013-10.226ZM18 9.907c-4.467 0-8.107 3.64-8.107 8.106 0 4.467 3.64 8.107 8.107 8.107 4.467 0 8.107-3.64 8.107-8.107 0-4.48-3.64-8.106-8.107-8.106Zm10.12 2.213-3.52-.76-.773-3.507L20.4 8.947l-2.427-2.654L15.56 8.96l-3.427-1.08-.76 3.52-3.506.773L8.973 15.6 6.32 18.027l2.667 2.413-1.08 3.427 3.52.76.773 3.506 3.427-1.093 2.426 2.653 2.414-2.666 3.426 1.08.76-3.52 3.507-.787-1.107-3.427 2.654-2.426-2.667-2.414 1.08-3.413Z" fill="#FFF"></path></g></svg>
# <g fill="none" fill-rule="evenodd"><path d="M18 0C8.053 0 0 8.053 0 18s8.053 18 18 18 18-8.053 18-18S27.947 0 18 0Z" fill="#EE5723"></path><path d="M12.88 12.947a7.243 7.243 0 0 1 10.24 0c2.813 2.826 2.827 7.413 0 10.226-2.827 2.827-7.413 2.827-10.227 0-2.826-2.813-2.826-7.4-.013-10.226ZM18 9.907c-4.467 0-8.107 3.64-8.107 8.106 0 4.467 3.64 8.107 8.107 8.107 4.467 0 8.107-3.64 8.107-8.107 0-4.48-3.64-8.106-8.107-8.106Zm10.12 2.213-3.52-.76-.773-3.507L20.4 8.947l-2.427-2.654L15.56 8.96l-3.427-1.08-.76 3.52-3.506.773L8.973 15.6 6.32 18.027l2.667 2.413-1.08 3.427 3.52.76.773 3.506 3.427-1.093 2.426 2.653 2.414-2.666 3.426 1.08.76-3.52 3.507-.787-1.107-3.427 2.654-2.426-2.667-2.414 1.08-3.413Z" fill="#FFF"></path></g>
# <path d="M18 0C8.053 0 0 8.053 0 18s8.053 18 18 18 18-8.053 18-18S27.947 0 18 0Z" fill="#EE5723"></path>
# <path d="M12.88 12.947a7.243 7.243 0 0 1 10.24 0c2.813 2.826 2.827 7.413 0 10.226-2.827 2.827-7.413 2.827-10.227 0-2.826-2.813-2.826-7.4-.013-10.226ZM18 9.907c-4.467 0-8.107 3.64-8.107 8.106 0 4.467 3.64 8.107 8.107 8.107 4.467 0 8.107-3.64 8.107-8.107 0-4.48-3.64-8.106-8.107-8.106Zm10.12 2.213-3.52-.76-.773-3.507L20.4 8.947l-2.427-2.654L15.56 8.96l-3.427-1.08-.76 3.52-3.506.773L8.973 15.6 6.32 18.027l2.667 2.413-1.08 3.427 3.52.76.773 3.506 3.427-1.093 2.426 2.653 2.414-2.666 3.426 1.08.76-3.52 3.507-.787-1.107-3.427 2.654-2.426-2.667-2.414 1.08-3.413Z" fill="#FFF"></path>
#
#
#
#
# <a class="social-link" data-gacategory="Facebook" data-galink="https://www.facebook.com/AccuWeather" data-gatype="social" href="https://www.facebook.com/AccuWeather" rel="noopener noreferrer" target="_blank">
# <svg alt="Social Icon" class="social-icon" data-src="/images/socialicons/facebook.svg" height="32" viewbox="0 0 36 36" width="32"><g fill="none" fill-rule="nonzero"><path d="M20.8 5.069c-9.946 0-11.514 4.3-11.514 14.247 0 8.092-1.997 5.082 5.346 7.352C16.315 27.188 16.145 36 18 36c1.72 0 3.383-.24 4.957-.69 2.408-.688 4.466-4.135 6.173-10.342 1.644-2.179 2.466-4.696 2.466-7.55 0-9.947-.85-12.35-10.796-12.35Z" fill="#FFF"></path><path d="M18 0C8.053 0 0 8.053 0 18c0 9.893 7.987 17.933 17.867 18V23.653h-4.16V18.84h4.16v-3.547c0-4.12 2.52-6.36 6.186-6.36 1.76 0 3.267.134 3.707.187v4.307h-2.547c-2 0-2.386.946-2.386 2.346v3.067H27.6l-.627 4.813h-4.146v11.694C30.427 33.227 36 26.267 36 18c0-9.947-8.053-18-18-18Z" fill="#4167B2"></path></g></svg>
# </a>
#
#
# <svg alt="Social Icon" class="social-icon" data-src="/images/socialicons/facebook.svg" height="32" viewbox="0 0 36 36" width="32"><g fill="none" fill-rule="nonzero"><path d="M20.8 5.069c-9.946 0-11.514 4.3-11.514 14.247 0 8.092-1.997 5.082 5.346 7.352C16.315 27.188 16.145 36 18 36c1.72 0 3.383-.24 4.957-.69 2.408-.688 4.466-4.135 6.173-10.342 1.644-2.179 2.466-4.696 2.466-7.55 0-9.947-.85-12.35-10.796-12.35Z" fill="#FFF"></path><path d="M18 0C8.053 0 0 8.053 0 18c0 9.893 7.987 17.933 17.867 18V23.653h-4.16V18.84h4.16v-3.547c0-4.12 2.52-6.36 6.186-6.36 1.76 0 3.267.134 3.707.187v4.307h-2.547c-2 0-2.386.946-2.386 2.346v3.067H27.6l-.627 4.813h-4.146v11.694C30.427 33.227 36 26.267 36 18c0-9.947-8.053-18-18-18Z" fill="#4167B2"></path></g></svg>
# <g fill="none" fill-rule="nonzero"><path d="M20.8 5.069c-9.946 0-11.514 4.3-11.514 14.247 0 8.092-1.997 5.082 5.346 7.352C16.315 27.188 16.145 36 18 36c1.72 0 3.383-.24 4.957-.69 2.408-.688 4.466-4.135 6.173-10.342 1.644-2.179 2.466-4.696 2.466-7.55 0-9.947-.85-12.35-10.796-12.35Z" fill="#FFF"></path><path d="M18 0C8.053 0 0 8.053 0 18c0 9.893 7.987 17.933 17.867 18V23.653h-4.16V18.84h4.16v-3.547c0-4.12 2.52-6.36 6.186-6.36 1.76 0 3.267.134 3.707.187v4.307h-2.547c-2 0-2.386.946-2.386 2.346v3.067H27.6l-.627 4.813h-4.146v11.694C30.427 33.227 36 26.267 36 18c0-9.947-8.053-18-18-18Z" fill="#4167B2"></path></g>
# <path d="M20.8 5.069c-9.946 0-11.514 4.3-11.514 14.247 0 8.092-1.997 5.082 5.346 7.352C16.315 27.188 16.145 36 18 36c1.72 0 3.383-.24 4.957-.69 2.408-.688 4.466-4.135 6.173-10.342 1.644-2.179 2.466-4.696 2.466-7.55 0-9.947-.85-12.35-10.796-12.35Z" fill="#FFF"></path>
# <path d="M18 0C8.053 0 0 8.053 0 18c0 9.893 7.987 17.933 17.867 18V23.653h-4.16V18.84h4.16v-3.547c0-4.12 2.52-6.36 6.186-6.36 1.76 0 3.267.134 3.707.187v4.307h-2.547c-2 0-2.386.946-2.386 2.346v3.067H27.6l-.627 4.813h-4.146v11.694C30.427 33.227 36 26.267 36 18c0-9.947-8.053-18-18-18Z" fill="#4167B2"></path>
#
#
#
#
# <a class="social-link" data-gacategory="Twitter" data-galink="https://twitter.com/BreakingWeather" data-gatype="social" href="https://twitter.com/BreakingWeather" rel="noopener noreferrer" target="_blank">
# <svg alt="Social Icon" class="social-icon" data-src="/images/socialicons/twitter.svg" height="32" viewbox="0 0 36 36" width="32"><g fill="none" fill-rule="nonzero"><path d="M18 0C8.053 0 0 8.053 0 18s8.053 18 18 18 18-8.053 18-18S27.947 0 18 0Z" fill="#1DA1F3"></path><path d="M26.904 14.316c.012.183.012.376.012.57 0 5.774-4.294 12.448-12.14 12.448a11.96 11.96 0 0 1-6.538-1.96c.33.046.672.058 1.014.058a8.424 8.424 0 0 0 5.296-1.868c-1.868-.034-3.44-1.298-3.987-3.04.262.056.524.079.798.079.387 0 .763-.057 1.127-.16-1.947-.398-3.428-2.163-3.428-4.293v-.057c.581.33 1.23.524 1.936.547a4.417 4.417 0 0 1-1.902-3.645c0-.797.205-1.549.581-2.198 2.107 2.654 5.25 4.385 8.792 4.567a4.717 4.717 0 0 1-.114-.99c0-2.415 1.914-4.374 4.26-4.374 1.23 0 2.335.535 3.109 1.378a8.26 8.26 0 0 0 2.71-1.06 4.3 4.3 0 0 1-1.879 2.415A8.4 8.4 0 0 0 29 12.05c-.535.877-1.264 1.64-2.096 2.266Z" fill="#FFF"></path></g></svg>
# </a>
#
#
# <svg alt="Social Icon" class="social-icon" data-src="/images/socialicons/twitter.svg" height="32" viewbox="0 0 36 36" width="32"><g fill="none" fill-rule="nonzero"><path d="M18 0C8.053 0 0 8.053 0 18s8.053 18 18 18 18-8.053 18-18S27.947 0 18 0Z" fill="#1DA1F3"></path><path d="M26.904 14.316c.012.183.012.376.012.57 0 5.774-4.294 12.448-12.14 12.448a11.96 11.96 0 0 1-6.538-1.96c.33.046.672.058 1.014.058a8.424 8.424 0 0 0 5.296-1.868c-1.868-.034-3.44-1.298-3.987-3.04.262.056.524.079.798.079.387 0 .763-.057 1.127-.16-1.947-.398-3.428-2.163-3.428-4.293v-.057c.581.33 1.23.524 1.936.547a4.417 4.417 0 0 1-1.902-3.645c0-.797.205-1.549.581-2.198 2.107 2.654 5.25 4.385 8.792 4.567a4.717 4.717 0 0 1-.114-.99c0-2.415 1.914-4.374 4.26-4.374 1.23 0 2.335.535 3.109 1.378a8.26 8.26 0 0 0 2.71-1.06 4.3 4.3 0 0 1-1.879 2.415A8.4 8.4 0 0 0 29 12.05c-.535.877-1.264 1.64-2.096 2.266Z" fill="#FFF"></path></g></svg>
# <g fill="none" fill-rule="nonzero"><path d="M18 0C8.053 0 0 8.053 0 18s8.053 18 18 18 18-8.053 18-18S27.947 0 18 0Z" fill="#1DA1F3"></path><path d="M26.904 14.316c.012.183.012.376.012.57 0 5.774-4.294 12.448-12.14 12.448a11.96 11.96 0 0 1-6.538-1.96c.33.046.672.058 1.014.058a8.424 8.424 0 0 0 5.296-1.868c-1.868-.034-3.44-1.298-3.987-3.04.262.056.524.079.798.079.387 0 .763-.057 1.127-.16-1.947-.398-3.428-2.163-3.428-4.293v-.057c.581.33 1.23.524 1.936.547a4.417 4.417 0 0 1-1.902-3.645c0-.797.205-1.549.581-2.198 2.107 2.654 5.25 4.385 8.792 4.567a4.717 4.717 0 0 1-.114-.99c0-2.415 1.914-4.374 4.26-4.374 1.23 0 2.335.535 3.109 1.378a8.26 8.26 0 0 0 2.71-1.06 4.3 4.3 0 0 1-1.879 2.415A8.4 8.4 0 0 0 29 12.05c-.535.877-1.264 1.64-2.096 2.266Z" fill="#FFF"></path></g>
# <path d="M18 0C8.053 0 0 8.053 0 18s8.053 18 18 18 18-8.053 18-18S27.947 0 18 0Z" fill="#1DA1F3"></path>
# <path d="M26.904 14.316c.012.183.012.376.012.57 0 5.774-4.294 12.448-12.14 12.448a11.96 11.96 0 0 1-6.538-1.96c.33.046.672.058 1.014.058a8.424 8.424 0 0 0 5.296-1.868c-1.868-.034-3.44-1.298-3.987-3.04.262.056.524.079.798.079.387 0 .763-.057 1.127-.16-1.947-.398-3.428-2.163-3.428-4.293v-.057c.581.33 1.23.524 1.936.547a4.417 4.417 0 0 1-1.902-3.645c0-.797.205-1.549.581-2.198 2.107 2.654 5.25 4.385 8.792 4.567a4.717 4.717 0 0 1-.114-.99c0-2.415 1.914-4.374 4.26-4.374 1.23 0 2.335.535 3.109 1.378a8.26 8.26 0 0 0 2.71-1.06 4.3 4.3 0 0 1-1.879 2.415A8.4 8.4 0 0 0 29 12.05c-.535.877-1.264 1.64-2.096 2.266Z" fill="#FFF"></path>
#
#
#
#
# <a class="social-link" data-gacategory="TV" data-galink="https://getaccuweather.tv" data-gatype="outbound" href="https://getaccuweather.tv/?utm_source=adc&amp;utm_medium=icon&amp;utm_campaign=footer" rel="noopener noreferrer" target="_blank">
# <svg alt="Social Icon" class="social-icon" data-src="/images/socialicons/tv.svg" height="32" viewbox="0 0 36 36" width="32"><g fill="none" fill-rule="evenodd"><circle cx="18" cy="18" fill="#F05514" r="18"></circle><g fill="#FFF"><path d="M10.933 15.533H7.88v-2.08h8.44v2.08h-3.04v8.6h-2.347zM17.52 13.453h2.68l2.64 7h.027l2.68-7h2.52l-4.4 10.68h-1.88z"></path></g></g></svg>
# </a>
#
#
# <svg alt="Social Icon" class="social-icon" data-src="/images/socialicons/tv.svg" height="32" viewbox="0 0 36 36" width="32"><g fill="none" fill-rule="evenodd"><circle cx="18" cy="18" fill="#F05514" r="18"></circle><g fill="#FFF"><path d="M10.933 15.533H7.88v-2.08h8.44v2.08h-3.04v8.6h-2.347zM17.52 13.453h2.68l2.64 7h.027l2.68-7h2.52l-4.4 10.68h-1.88z"></path></g></g></svg>
# <g fill="none" fill-rule="evenodd"><circle cx="18" cy="18" fill="#F05514" r="18"></circle><g fill="#FFF"><path d="M10.933 15.533H7.88v-2.08h8.44v2.08h-3.04v8.6h-2.347zM17.52 13.453h2.68l2.64 7h.027l2.68-7h2.52l-4.4 10.68h-1.88z"></path></g></g>
# <circle cx="18" cy="18" fill="#F05514" r="18"></circle>
# <g fill="#FFF"><path d="M10.933 15.533H7.88v-2.08h8.44v2.08h-3.04v8.6h-2.347zM17.52 13.453h2.68l2.64 7h.027l2.68-7h2.52l-4.4 10.68h-1.88z"></path></g>
# <path d="M10.933 15.533H7.88v-2.08h8.44v2.08h-3.04v8.6h-2.347zM17.52 13.453h2.68l2.64 7h.027l2.68-7h2.52l-4.4 10.68h-1.88z"></path>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="footer-legalese">
# <div class="footer-copyright">
# <span>
# 			© 2021 AccuWeather, Inc. "AccuWeather" and sun design are registered trademarks of AccuWeather, Inc. All Rights Reserved.
# 		</span>
# </div>
# <div class="footer-terms" id="footer-terms">
# <a data-ga="Terms of usage" href="/en/legal" target="_blank">
# 			Terms of Use
# 		</a>
# 		|
# 		<a data-ga="Privacy Policy" href="/en/privacy" target="_blank">
# 			Privacy Policy
# 		</a>
# 		|
# 		<a data-ga="Cookie Policy" href="/en/cookiepolicy" target="_blank">
# 			Cookie Policy
# 		</a>
# 		|
# 		<a data-ga="TAG Disclosure" href="/en/tag-publisher-sourcing-disclosure" target="_blank">
# 			TAG Disclosure
# 		</a>
# </div>
# </div>
#
#
# <div class="footer-copyright">
# <span>
# 			© 2021 AccuWeather, Inc. "AccuWeather" and sun design are registered trademarks of AccuWeather, Inc. All Rights Reserved.
# 		</span>
# </div>
#
#
# <span>
# 			© 2021 AccuWeather, Inc. "AccuWeather" and sun design are registered trademarks of AccuWeather, Inc. All Rights Reserved.
# 		</span>
#
# 			© 2021 AccuWeather, Inc. "AccuWeather" and sun design are registered trademarks of AccuWeather, Inc. All Rights Reserved.
#
#
#
#
#
# <div class="footer-terms" id="footer-terms">
# <a data-ga="Terms of usage" href="/en/legal" target="_blank">
# 			Terms of Use
# 		</a>
# 		|
# 		<a data-ga="Privacy Policy" href="/en/privacy" target="_blank">
# 			Privacy Policy
# 		</a>
# 		|
# 		<a data-ga="Cookie Policy" href="/en/cookiepolicy" target="_blank">
# 			Cookie Policy
# 		</a>
# 		|
# 		<a data-ga="TAG Disclosure" href="/en/tag-publisher-sourcing-disclosure" target="_blank">
# 			TAG Disclosure
# 		</a>
# </div>
#
#
# <a data-ga="Terms of usage" href="/en/legal" target="_blank">
# 			Terms of Use
# 		</a>
#
# 			Terms of Use
#
#
# 		|
#
# <a data-ga="Privacy Policy" href="/en/privacy" target="_blank">
# 			Privacy Policy
# 		</a>
#
# 			Privacy Policy
#
#
# 		|
#
# <a data-ga="Cookie Policy" href="/en/cookiepolicy" target="_blank">
# 			Cookie Policy
# 		</a>
#
# 			Cookie Policy
#
#
# 		|
#
# <a data-ga="TAG Disclosure" href="/en/tag-publisher-sourcing-disclosure" target="_blank">
# 			TAG Disclosure
# 		</a>
#
# 			TAG Disclosure
#
#
#
#
#
#
#
#
#
# <div class="glacier-ad unrendered oop" data-ad-type="oop" data-viewport="" id="oop"></div>
#
#
# <div class="glacier-ad unrendered interstitial" data-ad-type="interstitial" data-viewport="" id="interstitial"></div>
#
#
# <div class="privacy-policy-banner" data-banner-delay="0" data-banner-order="0" id="privacy-policy-banner">
# <div class="banner-body">
# <p>
# 				We have updated our <a href="/en/privacy" id="privacy-policy-banner-privacy-link" target="_blank">Privacy Policy</a> and <a href="/en/cookiepolicy" id="privacy-policy-banner-cookie-policy-link" target="_blank">Cookie Policy</a>.
# 			</p>
# <div class="banner-button policy-accept">I Understand</div>
# </div>
# </div>
#
#
# <div class="banner-body">
# <p>
# 				We have updated our <a href="/en/privacy" id="privacy-policy-banner-privacy-link" target="_blank">Privacy Policy</a> and <a href="/en/cookiepolicy" id="privacy-policy-banner-cookie-policy-link" target="_blank">Cookie Policy</a>.
# 			</p>
# <div class="banner-button policy-accept">I Understand</div>
# </div>
#
#
# <p>
# 				We have updated our <a href="/en/privacy" id="privacy-policy-banner-privacy-link" target="_blank">Privacy Policy</a> and <a href="/en/cookiepolicy" id="privacy-policy-banner-cookie-policy-link" target="_blank">Cookie Policy</a>.
# 			</p>
#
# 				We have updated our
# <a href="/en/privacy" id="privacy-policy-banner-privacy-link" target="_blank">Privacy Policy</a>
# Privacy Policy
#  and
# <a href="/en/cookiepolicy" id="privacy-policy-banner-cookie-policy-link" target="_blank">Cookie Policy</a>
# Cookie Policy
# .
#
#
#
# <div class="banner-button policy-accept">I Understand</div>
# I Understand
#
#
#
#
#
#
# <div class="feedback-banner hide-mobile" id="feedback-banner">
# <a class="feedback-banner-link" href="https://corporate.accuweather.com/company/contact/">
# <span>FEEDBACK</span>
# <svg class="icon-plus icon-plus" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg">
# <g fill="none" fill-rule="evenodd" stroke="#F05514" stroke-linecap="square" stroke-width="2">
# <path d="M9 0v18M0 9h18"></path>
# </g>
# </svg>
# </a>
# </div>
#
#
# <a class="feedback-banner-link" href="https://corporate.accuweather.com/company/contact/">
# <span>FEEDBACK</span>
# <svg class="icon-plus icon-plus" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg">
# <g fill="none" fill-rule="evenodd" stroke="#F05514" stroke-linecap="square" stroke-width="2">
# <path d="M9 0v18M0 9h18"></path>
# </g>
# </svg>
# </a>
#
#
# <span>FEEDBACK</span>
# FEEDBACK
#
#
# <svg class="icon-plus icon-plus" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg">
# <g fill="none" fill-rule="evenodd" stroke="#F05514" stroke-linecap="square" stroke-width="2">
# <path d="M9 0v18M0 9h18"></path>
# </g>
# </svg>
#
#
# <g fill="none" fill-rule="evenodd" stroke="#F05514" stroke-linecap="square" stroke-width="2">
# <path d="M9 0v18M0 9h18"></path>
# </g>
#
#
# <path d="M9 0v18M0 9h18"></path>

# %%
# Get the content of a tag
print(soup.body.div.header.contents)
print(soup.children)

# %%
#Get the string of a tag (only if no more children)
print(soup.body.div.header.h1.string)

# %%
#Finding all
print(soup.div.header.div.find_all('a'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\leila\OneDrive\Рабочий стол\IKT\lects\lect6\Lecture_6_correction.ipynb Ячейка 31 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/leila/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/IKT/lects/lect6/Lecture_6_correction.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> #Finding all
# ----> <a href='vscode-notebook-cell:/c%3A/Users/leila/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/IKT/lects/lect6/Lecture_6_correction.ipynb#X42sZmlsZQ%3D%3D?line=1'>2</a> print(soup.div.header.div.find_all('a'))
#       <a href='vscode-notebook-cell:/c%3A/Users/leila/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/IKT/lects/lect6/Lecture_6_correction.ipynb#X42sZmlsZQ%3D%3D?line=2'>3</a> print(soup.body)
#
# NameError: name 'soup' is not defined

# %%
# more about find_all
# filtering with id
headers = {'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:105.0) Gecko/20100101 Firefox/105.0'}
resp = requests.get('https://www.accuweather.com/en/kz/almaty/222191/weather-forecast/222191', headers = headers)
soup = BeautifulSoup(resp.content, 'html.parser')

print(soup.find_all('div', id = 'bottom'))

# %%
#filtering with class
print(soup.find_all('div', class_ = 'page-subnav'))

# %%
#filtering with several attribute
attrs = {'class' : 'header-city-link'}
print(soup.find_all('div', attrs))

# %%
print(soup.find_all('a', attrs)[0]['href'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\leila\OneDrive\Рабочий стол\IKT\lects\lect6\Lecture_6_correction.ipynb Ячейка 35 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/leila/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/IKT/lects/lect6/Lecture_6_correction.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> print(soup.find_all('a', attrs)[0]['href'])
#
# NameError: name 'soup' is not defined

# %%
#YOUR TURN : Get the current temperature and today air quality in the weather website
#10 minutes
import requests
from bs4 import BeautifulSoup
headers = {'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:105.0) Gecko/20100101 Firefox/105.0'}
resp = requests.get('https://www.accuweather.com/en/kz/almaty/222191/weather-forecast/222191', headers = headers)
soup = BeautifulSoup(resp.content, 'html.parser')

# %%
attrs = ('')
print(soup.find_all('a', class_ = 'cur-con-weather-card')[0].find_all('div', class_ = 'temp'))
# print(soup.find_all('div', class_ = 'page-column-1')[0].find_all('div', class_ = 'temp'))
# Out:
# [<div class="temp">12°<span class="after-temp">C</span></div>]

# %% [markdown]
# # Test with KBTU website

# %%
#Your Turn:
#Get all image of KBTU website
#Then get image of academic staff only
